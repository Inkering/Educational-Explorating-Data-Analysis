# %% [markdown]
# # Preliminary Exploration Notebook

# %%
import pandas as pd
import numpy as np

# %%
school_data = pd.read_csv("data/CRDC 2015-16 School Data.csv", encoding = "ISO-8859-1")
school_layout = pd.read_csv("data/CRDC 2015-16 School Data Record Layout.csv", encoding = "ISO-8859-1")
school_data = school_data[school_data.SCH_GRADE_G09=='Yes']
school_data = school_data[school_data.SCH_GRADE_G10 == 'Yes']
school_data = school_data[school_data.SCH_GRADE_G11 == 'Yes']
school_data = school_data[school_data.SCH_GRADE_G12 == 'Yes']
school_data = school_data[school_data.JJ == 'No']
len(school_data)
school_data.reset_index(drop=True,inplace=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,6,23,24,25,30,31,1828) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
school_data[school_data.LEA_STATE_NAME == 'ARKANSAS']
# Out:
#      LEA_STATE LEA_STATE_NAME   LEAID                            LEA_NAME  \
# 1099        AR       ARKANSAS  500001              DEWITT SCHOOL DISTRICT
# 1100        AR       ARKANSAS  500006              WARREN SCHOOL DISTRICT
# 1101        AR       ARKANSAS  500009             CORNING SCHOOL DISTRICT
# 1102        AR       ARKANSAS  500012           RIVERSIDE SCHOOL DISTRICT
# 1103        AR       ARKANSAS  500016           MARMADUKE SCHOOL DISTRICT
# 1104        AR       ARKANSAS  500017           PARAGOULD SCHOOL DISTRICT
# 1105        AR       ARKANSAS  500017           PARAGOULD SCHOOL DISTRICT
# 1106        AR       ARKANSAS  500020             MIDLAND SCHOOL DISTRICT
# 1107        AR       ARKANSAS  500021        IZARD CO. CONS. SCHOOL DIST.
# 1108        AR       ARKANSAS  500023             NEWPORT SCHOOL DISTRICT
# 1109        AR       ARKANSAS  500028           STAR CITY SCHOOL DISTRICT
# 1110        AR       ARKANSAS  500029             GOSNELL SCHOOL DISTRICT
# 1111        AR       ARKANSAS  500030              NEVADA SCHOOL DISTRICT
# 1112        AR       ARKANSAS  500032             BEARDEN SCHOOL DISTRICT
# 1113        AR       ARKANSAS  500035           ARK. SCHOOL FOR THE BLIND
# 1114        AR       ARKANSAS  500036            ARK. SCHOOL FOR THE DEAF
# 1115        AR       ARKANSAS  500041       WESTERN YELL CO. SCHOOL DIST.
# 1116        AR       ARKANSAS  500042             HAMBURG SCHOOL DISTRICT
# 1117        AR       ARKANSAS  500043       MOUNTAIN HOME SCHOOL DISTRICT
# 1118        AR       ARKANSAS  500046              MANILA SCHOOL DISTRICT
# 1119        AR       ARKANSAS  500047             TRUMANN SCHOOL DISTRICT
# 1120        AR       ARKANSAS  500048      EAST POINSETT CO. SCHOOL DIST.
# 1121        AR       ARKANSAS  500051       PALESTINE-WHEATLEY SCH. DIST.
# 1122        AR       ARKANSAS  500055               ARKANSAS ARTS ACADEMY
# 1123        AR       ARKANSAS  500059       ACADEMICS PLUS CHARTER SCHOOL
# 1124        AR       ARKANSAS  500062           KIPP DELTA PUBLIC SCHOOLS
# 1125        AR       ARKANSAS  500065    LAFAYETTE COUNTY SCHOOL DISTRICT
# 1126        AR       ARKANSAS  500067       CLEVELAND COUNTY SCHOOL DIST.
# 1127        AR       ARKANSAS  500068      EMERSON-TAYLOR SCHOOL DISTRICT
# 1128        AR       ARKANSAS  500068      EMERSON-TAYLOR SCHOOL DISTRICT
# 1318               -9               -9                -9               -9
# 1319               -9               -9                -9               -9
# 1320               -9               -9                -9               -9
# 1321               -9               -9                -9               -9
# 1322               -9               -9                -9               -9
# 1323               -9               -9                -9               -9
# 1324               -9               -9                -9               -9
# 1325               -9               -9                -9               -9
# 1326               -9               -9                -9               -9
# 1327               -9               -9                -9               -9
# 1328               -9               -9                -9               -9
# 1329               -9               -9                -9               -9
# 1330               -9               -9                -9               -9
# 1331               -9               -9                -9               -9
# 1332               -9               -9                -9               -9
# 1333               -9               -9                -9               -9
# 1334               -9               -9                -9               -9
# 1335               -9               -9                -9               -9
# 1336               -9               -9                -9               -9
# 1337               -9               -9                -9               -9
# 1338               -9               -9                -9               -9
# 1339               -9               -9                -9               -9
# 1340               -9               -9                -9               -9
# 1341               -9               -9                -9               -9
# 1342               -9               -9                -9               -9
# 1343               -9               -9                -9               -9
#
# [245 rows x 1836 columns]

# %%
school_data.head()
# Out:
#   LEA_STATE LEA_STATE_NAME   LEAID                LEA_NAME  SCHID  \
# 0        AL        ALABAMA  100002  Alabama Youth Services   1876
# 1        AL        ALABAMA  100005        Albertville City    871
# 2        AL        ALABAMA  100006         Marshall County    872
# 3        AL        ALABAMA  100006         Marshall County    878
# 4        AL        ALABAMA  100006         Marshall County    883
#
#                     SCH_NAME     COMBOKEY  JJ SCH_GRADE_PS SCH_GRADE_KG  \
# 0     Alabama Youth Services  10000201876  No           No           No
# 1       Albertville High Sch  10000500871  No           No           No
# 2                 Asbury Sch  10000600872  No           No           No
# 3           Douglas High Sch  10000600878  No           No           No
# 4  Kate D Smith DAR High Sch  10000600883  No           No           No
#
#         ...        SCH_FTESERVICES_PSY SCH_FTESERVICES_SOC SCH_JJTYPE  \
# 0       ...                        0.0                 0.0         -9
# 1       ...                        0.0                 0.0         -9
# 2       ...                        0.0                 0.0         -9
# 3       ...                        0.0                 0.0         -9
# 4       ...                        0.0                 0.0         -9
#
#   SCH_JJSYDAYS SCH_JJHOURS SCH_JJPART_LT15 SCH_JJPART_15T30 SCH_JJPART_31T90  \
# 0           -9          -9              -9               -9               -9
# 1           -9          -9              -9               -9               -9
# 2           -9          -9              -9               -9               -9
# 3           -9          -9              -9               -9               -9
# 4           -9          -9              -9               -9               -9
#
#   SCH_JJPART_91T180 SCH_JJPART_OV180
# 0                -9               -9
# 1                -9               -9
# 2                -9               -9
# 3                -9               -9
# 4                -9               -9
#
# [5 rows x 1836 columns]

# %%
school_layout[school_layout["Field_Name"] == "SCH_JJHOURS"]["Field_Description"]
# Out:
# 1830    Justice Facility Educational Program Hours per...
# Name: Field_Description, dtype: object

# %%
school_layout
# Out:
#       Order Excel_Column_Finder             Field_Name  \
# 0         1                   A              LEA_STATE
# 1         2                   B         LEA_STATE_NAME
# 2         3                   C                  LEAID
# 3         4                   D               LEA_NAME
# 4         5                   E                  SCHID
# 5         6                   F               SCH_NAME
# 6         7                   G               COMBOKEY
# 7         8                   H                     JJ
# 8         9                   I           SCH_GRADE_PS
# 9        10                   J           SCH_GRADE_KG
# 10       11                   K          SCH_GRADE_G01
# 11       12                   L          SCH_GRADE_G02
# 12       13                   M          SCH_GRADE_G03
# 13       14                   N          SCH_GRADE_G04
# 14       15                   O          SCH_GRADE_G05
# 15       16                   P          SCH_GRADE_G06
# 16       17                   Q          SCH_GRADE_G07
# 17       18                   R          SCH_GRADE_G08
# 18       19                   S          SCH_GRADE_G09
# 19       20                   T          SCH_GRADE_G10
# 20       21                   U          SCH_GRADE_G11
# 21       22                   V          SCH_GRADE_G12
# 22       23                   W           SCH_GRADE_UG
# 23       24                   X        SCH_UGDETAIL_ES
# 24       25                   Y        SCH_UGDETAIL_MS
# 25       26                   Z        SCH_UGDETAIL_HS
# 26       27                  AA        SCH_STATUS_SPED
# 27       28                  AB      SCH_STATUS_MAGNET
# 28       29                  AC     SCH_STATUS_CHARTER
# 29       30                  AD         SCH_STATUS_ALT
# ...     ...                 ...                    ...
# 1806   1807                 BQM       SCH_FTE_AID_WFED
# 1807   1808                 BQN       SCH_SAL_AID_WFED
# 1808   1809                 BQO       SCH_FTE_SUP_WFED
# 1809   1810                 BQP       SCH_SAL_SUP_WFED
# 1810   1811                 BQQ       SCH_FTE_ADM_WFED
# 1811   1812                 BQR       SCH_SAL_ADM_WFED
# 1812   1813                 BQS   SCH_SAL_TOTPERS_WFED
# 1813   1814                 BQT           SCH_NPE_WFED
# 1814   1815                 BQU       SCH_FTETEACH_TOT
# 1815   1816                 BQV      SCH_FTETEACH_CERT
# 1816   1817                 BQW   SCH_FTETEACH_NOTCERT
# 1817   1818                 BQX        SCH_FTETEACH_FY
# 1818   1819                 BQY        SCH_FTETEACH_SY
# 1819   1820                 BQZ  SCH_TEACHERS_CURR_TOT
# 1820   1821                 BRA  SCH_TEACHERS_PREV_TOT
# 1821   1822                 BRB      SCH_FTECOUNSELORS
# 1822   1823                 BRC    SCH_FTETEACH_ABSENT
# 1823   1824                 BRD    SCH_FTESECURITY_LEO
# 1824   1825                 BRE    SCH_FTESECURITY_GUA
# 1825   1826                 BRF    SCH_FTESERVICES_NUR
# 1826   1827                 BRG    SCH_FTESERVICES_PSY
# 1827   1828                 BRH    SCH_FTESERVICES_SOC
# 1828   1829                 BRI             SCH_JJTYPE
# 1829   1830                 BRJ           SCH_JJSYDAYS
# 1830   1831                 BRK            SCH_JJHOURS
# 1831   1832                 BRL        SCH_JJPART_LT15
# 1832   1833                 BRM       SCH_JJPART_15T30
# 1833   1834                 BRN       SCH_JJPART_31T90
# 1834   1835                 BRO      SCH_JJPART_91T180
# 1835   1836                 BRP       SCH_JJPART_OV180
#
#                                       Field_Description  \
# 0                           District State Abbreviation
# 1                                   District State Name
# 2            7 Digit LEAID District Identification Code
# 3                                         District Name
# 4                    5 Digit School Identification Code
# 5                                           School Name
# 6     7 Digit LEAID District Identification Code+5 D...
# 7     Juvenile Justice Facility: "Yes" indicates a l...
# 8              Grades with Students Enrolled: Preschool
# 9           Grades with Students Enrolled: Kindergarten
# 10               Grades with Students Enrolled: Grade 1
# 11               Grades with Students Enrolled: Grade 2
# 12               Grades with Students Enrolled: Grade 3
# 13               Grades with Students Enrolled: Grade 4
# 14               Grades with Students Enrolled: Grade 5
# 15               Grades with Students Enrolled: Grade 6
# 16               Grades with Students Enrolled: Grade 7
# 17               Grades with Students Enrolled: Grade 8
# 18               Grades with Students Enrolled: Grade 9
# 19              Grades with Students Enrolled: Grade 10
# 20              Grades with Students Enrolled: Grade 11
# 21              Grades with Students Enrolled: Grade 12
# 22              Grades with Students Enrolled: Ungraded
# 23      Ungraded Detail: Elementary school age students
# 24          Ungraded Detail: Middle school age students
# 25            Ungraded Detail: High school age students
# 26     School Characteristics: Special education school
# 27    School Characteristics: Magnet school or schoo...
# 28               School Characteristics: Charter school
# 29           School Characteristics: Alternative school
# ...                                                 ...
# 1806  Full-time Equivalency Count of Instructional A...
# 1807  Salary Expenditures for Instructional Aides Fu...
# 1808  Full-time Equivalency Count of Support Service...
# 1809  Salary Expenditures for Support Services Staff...
# 1810  Full-time Equivalency Count of School Administ...
# 1811  Salary Expenditures for  School Administration...
# 1812  Salary Expenditures for Total Personnel (instr...
# 1813  Amount of Non-Personnel Expenditures Associate...
# 1814                              Total FTE of Teachers
# 1815           Number of FTE teachers who are certified
# 1816       Number of FTE teachers who are not certified
# 1817  Number of FTE teachers in their first year of ...
# 1818  Number of FTE teachers in their second year of...
# 1819             Number of current school year teachers
# 1820            Number of previous school year teachers
# 1821                    Number of FTE school counselors
# 1822  Number of FTE teachers who were absent more th...
# 1823       Number of FTE sworn law enforcement officers
# 1824                      Number of FTE security guards
# 1825                               Number of FTE nurses
# 1826                        Number of FTE psychologists
# 1827                       Number of FTE social workers
# 1828                              Justice Facility Type
# 1829    Days in Regular School Year at Justice Facility
# 1830  Justice Facility Educational Program Hours per...
# 1831  Students who participated in credit granting e...
# 1832  Students who participated in credit granting e...
# 1833  Students who participated in credit granting e...
# 1834  Students who participated in credit granting e...
# 1835  Students who participated in credit granting e...
#
#                       Module
# 0             Identification
# 1             Identification
# 2             Identification
# 3             Identification
# 4             Identification
# 5             Identification
# 6             Identification
# 7             Identification
# 8     School Characteristics
# 9     School Characteristics
# 10    School Characteristics
# 11    School Characteristics
# 12    School Characteristics
# 13    School Characteristics
# 14    School Characteristics
# 15    School Characteristics
# 16    School Characteristics
# 17    School Characteristics
# 18    School Characteristics
# 19    School Characteristics
# 20    School Characteristics
# 21    School Characteristics
# 22    School Characteristics
# 23    School Characteristics
# 24    School Characteristics
# 25    School Characteristics
# 26    School Characteristics
# 27    School Characteristics
# 28    School Characteristics
# 29    School Characteristics
# ...                      ...
# 1806     School Expenditures
# 1807     School Expenditures
# 1808     School Expenditures
# 1809     School Expenditures
# 1810     School Expenditures
# 1811     School Expenditures
# 1812     School Expenditures
# 1813     School Expenditures
# 1814          School Support
# 1815          School Support
# 1816          School Support
# 1817          School Support
# 1818          School Support
# 1819          School Support
# 1820          School Support
# 1821          School Support
# 1822          School Support
# 1823          School Support
# 1824          School Support
# 1825          School Support
# 1826          School Support
# 1827          School Support
# 1828        Justice Facility
# 1829        Justice Facility
# 1830        Justice Facility
# 1831        Justice Facility
# 1832        Justice Facility
# 1833        Justice Facility
# 1834        Justice Facility
# 1835        Justice Facility
#
# [1836 rows x 5 columns]

# %% [markdown]
# **Note:**  For cell values in the school data frame, negative numbers have special meanings as follows:
# -2 means small cell values,
# -5 means there is an action plan (next survey),
# -6 Force Certified (missing data),
# -7 System error,
# -8 EDFacts Missing Data,
# -9 means not applicable / skipped

# %%
# print(len(school_data[school_data["LEA_STATE_NAME"] == "CALIFORNIA"]))
nul_vals = [-2,-5,-6,-7,-8,-9, '-2', '-5', '-6','-7','-8','-9']
for (columnName, columnData) in school_data.iteritems():
    continue
     #print(round(len(school_data[columnName][school_data[columnName].isin(nul_vals)])/school_data.shape[0], 3), columnName);

# %%
nul_vals = [-2,-5,-6,-7,-8,-9, '-2', '-5', '-6','-7','-8','-9']
# for (columnName, columnData) in school_data.iteritems():
column = "SCH_JJTYPE"
print(school_data[column].unique())
#print(school_data[column][~school_data[column].isin(nul_vals)])
# Out:
# [-9 '-9']

# %%
def percentage_of_students(school_layout, school_data,layout_a_start,layout_a_stop):
    enrollment = []
    np.seterr(divide = 'ignore')
    enroll_categories = range(layout_a_start,layout_a_stop+1,1)
    enrollment_vals = np.empty([len(enroll_categories)*len(school_data)])
    enrollment_vals.shape = [len(enroll_categories),len(school_data)]
    for i in range(len(enroll_categories)):
        j = enroll_categories[i]
        print(school_layout['Field_Description'][school_layout['Order']==j].values[0])
        enrollment.append(str(school_layout['Field_Name'][school_layout['Order']==j].values[0]))
        nul_bool = school_data[enrollment[-1]].isin(nul_vals)
        value = np.array(school_data[enrollment[-1]])
        value[nul_bool] = 0
        if i == 0:
            enrollment_vals[0] = value
        else:
            enrollment_vals[i] = value
    return(enrollment_vals)


enrollment = percentage_of_students(school_layout,school_data,56,71)
suspensions = percentage_of_students(school_layout,school_data,822,837)
print(len(enrollment),len(suspensions))
suspensions = np.array(suspensions, dtype=float)
percentages = suspensions/enrollment
percentages = np.nan_to_num(percentages)

print('\n\nPERCENT GROUP SUSPENDED:\n',percentages*100)
print('\n\nAVERAGE NUMBER OF STUDENTS SUSPENDED IN AN AVERAGE SCHOOL:\n',np.round(np.mean(suspensions,axis=1),3))
print('\n\nAVERAGE NUMBER OF STUDENTS IN AN AVERAGE SCHOOL:\n',np.round(np.mean(enrollment,axis=1),3))
print('\n\nAVERAGE PERCENTAGE OF STUDENTS SUSPENDED IN AN AVERAGE SCHOOL:\n',100*np.round(np.mean(suspensions,axis=1)/np.mean(enrollment,axis=1),3))
# Out:
# Overall Student Enrollment: Hispanic Male
# Overall Student Enrollment: Hispanic Female
# Overall Student Enrollment: American Indian/Alaska Native Male
# Overall Student Enrollment: American Indian/Alaska Native Female
# Overall Student Enrollment: Asian Male
# Overall Student Enrollment: Asian Female
# Overall Student Enrollment: Native Hawaiian/Pacific Islander Male
# Overall Student Enrollment: Native Hawaiian/Pacific Islander Female
# Overall Student Enrollment: Black Male
# Overall Student Enrollment: Black Female
# Overall Student Enrollment: White Male
# Overall Student Enrollment: White Female
# Overall Student Enrollment: Two or More Races Male
# Overall Student Enrollment: Two or More Races Female
# Overall Student Enrollment: Calculated Male Total
# Overall Student Enrollment: Calculated Female Total
# Students without disabilities who received only one out-of-school suspension: Hispanic Male
# Students without disabilities who received only one out-of-school suspension: Hispanic Female
# Students without disabilities who received only one out-of-school suspension: American Indian/Alaska Native Male
# Students without disabilities who received only one out-of-school suspension: American Indian/Alaska Native Female
# Students without disabilities who received only one out-of-school suspension: Asian Male
# Students without disabilities who received only one out-of-school suspension: Asian Female
# Students without disabilities who received only one out-of-school suspension: Native Hawaiian/Pacific Islander Male
# Students without disabilities who received only one out-of-school suspension: Native Hawaiian/Pacific Islander Female
# Students without disabilities who received only one out-of-school suspension: Black Male
# Students without disabilities who received only one out-of-school suspension: Black Female
# Students without disabilities who received only one out-of-school suspension: White Male
# Students without disabilities who received only one out-of-school suspension: White Female
# Students without disabilities who received only one out-of-school suspension: Two or More Races Male
# Students without disabilities who received only one out-of-school suspension: Two or More Races Female
# Total number of students without disabilities who received only one out-of-school suspension: Calculated Male Total
# Total number of students without disabilities who received only one out-of-school suspension: Calculated Female Total
# 16 16
#
#
# PERCENT GROUP SUSPENDED:
#  [[  0.           5.38461538   0.         ...,   0.           0.           0.        ]
#  [  0.           0.90497738   2.10526316 ...,   0.           0.           0.        ]
#  [  0.           0.           0.         ...,   0.           0.
#    12.72727273]
#  ...,
#  [  0.           0.           0.         ...,   0.           0.           0.        ]
#  [  0.           4.65116279   1.73010381 ...,   0.           9.52380952
#    12.72727273]
#  [  0.           0.61538462   0.8        ...,   0.          22.22222222
#     7.47663551]]
#
#
# AVERAGE NUMBER OF STUDENTS SUSPENDED IN AN AVERAGE SCHOOL:
#  [  3.579   2.083   0.257   0.172   0.308   0.131   0.071   0.046   4.62
#    3.849   5.904   2.861   0.543   0.38   15.283   9.521]
#
#
# AVERAGE NUMBER OF STUDENTS IN AN AVERAGE SCHOOL:
#  [  84.328   80.791    4.176    3.988   17.532   16.986    1.506    1.43
#    54.861   53.448  182.161  172.382    9.875    9.858  354.437  338.883]
#
#
# AVERAGE PERCENTAGE OF STUDENTS SUSPENDED IN AN AVERAGE SCHOOL:
#  [ 4.2  2.6  6.2  4.3  1.8  0.8  4.7  3.2  8.4  7.2  3.2  1.7  5.5  3.9  4.3
#   2.8]
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:25: RuntimeWarning: invalid value encountered in true_divide

# %%
#ASK FOR USER INPUT
race_sex_breakdown_order = ['Hispanic Male','Hispanic Female','American Indian/Alaska Native Male','American Indian/Alaska Native Female','Asian Male','Asian Female','Native Hawaiian/Pacific Islander Male','Native Hawaiian/Pacific Islander Female','Black Male','Black Female','White Male','White Female','Two or More Races Male','Two or More Races Female','Calculated Male Total','Calculated Female Total']
school_name_part = input('Please Type Some of The Name of Your School:')
your_school = school_data[school_data['SCH_NAME'].str.contains(school_name_part)].index
#ASKING FOR MORE SPECIFICITY
YOUR_SCHOOL = -1
while YOUR_SCHOOL == -1:
    if len(your_school) > 1:
        for t in range(len(your_school)):
            left_aligned = str(t)+': '+str(school_data.SCH_NAME.ix[your_school].values[t])
            center = school_data.LEA_STATE_NAME.ix[your_school].values[t]
            right_aligned = str(school_data.LEA_NAME.ix[your_school].values[t])
            print("{1:<40}{0:^25}{2:>50}".format(center, left_aligned, right_aligned))
        school_select = int(input('Please Type the Number Corresponding to Your School: '))
        left_aligned = str(t)+': '+str(school_data.SCH_NAME.ix[your_school].values[school_select]);
        center = school_data.LEA_STATE_NAME.ix[your_school].values[school_select];
        right_aligned = str(school_data.LEA_NAME.ix[your_school].values[school_select]);
        print("{1:<40}{0:^25}{2:>50}".format(center, left_aligned, right_aligned))
        YOUR_SCHOOL = your_school[school_select]
        print(YOUR_SCHOOL)
        print(school_data['SCH_NAME'].ix[YOUR_SCHOOL])
    elif len(your_school) == 1:
        right_aligned = school_data.LEA_STATE_NAME.ix[your_school].values[0]
        left_aligned = str(school_data.SCH_NAME.ix[your_school].values[0])
        center = ' '
        print("{1:<40}{0:^25}{2:>20}".format(center, left_aligned, right_aligned))
        YOUR_SCHOOL = your_school
    else:
        print('Uh Oh. WE COULD NOT FIND YOUR SCHOOL. PLEASE TRY ANOTHER SEARCH WORD.')
        break
your_percentages = np.round(100*percentages[:,YOUR_SCHOOL],1)
print('\n','\n',"{1:<20}{0:^40}{2:>50}".format('% Suspended', 'Sex/Race Subgroup', 'Number of Enrolled Students'))
print('-------------------------------------------------------------------------------------------------------------')
for index in range(len(your_percentages)):
    center = race_sex_breakdown_order[index];
    left_aligned = str(float(your_percentages[index]));
    right_aligned = str(float(enrollment[:,YOUR_SCHOOL][index]));
    
    print("{1:<20}{0:^40}{2:>50}".format(center, left_aligned, right_aligned))
# Out:
# Please Type Some of The Name of Your School:Gunn High
# Henry M. Gunn High                                                         CALIFORNIA
#
#
#  Sex/Race Subgroup                 % Suspended                                      Number of Enrolled Students
# -------------------------------------------------------------------------------------------------------------
# 0.0                              Hispanic Male                                                            86.0
# 0.0                             Hispanic Female                                                           89.0
# 0.0                    American Indian/Alaska Native Male                                                  0.0
# 0.0                   American Indian/Alaska Native Female                                                 2.0
# 0.4                                Asian Male                                                            455.0
# 1.2                               Asian Female                                                           416.0
# 0.0                  Native Hawaiian/Pacific Islander Male                                                 2.0
# 0.0                 Native Hawaiian/Pacific Islander Female                                                2.0
# 0.0                                Black Male                                                             14.0
# 0.0                               Black Female                                                            11.0
# 0.5                                White Male                                                            386.0
# 0.0                               White Female                                                           350.0
# 3.2                          Two or More Races Male                                                       62.0
# 0.0                         Two or More Races Female                                                      65.0
# 0.6                          Calculated Male Total                                                      1005.0
# 0.5                         Calculated Female Total                                                      935.0

# %% [markdown]
# ## Input Parameters:
#
# #### School Expenditure per student:
# (school_data.SCH_SAL_TOTPERS_WFED+school_data.SCH_NPE_WFED) / (school_data.TOT_ENR_M + school.data.TOT_ENR_F)
#
# #### Percentage of Population a Particular Racial Group:
# (school_data.SCH_ENR_HI_M+school_data.SCH_ENR_HI_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
# (school_data.SCH_ENR_AM_M+school_data.SCH_ENR_AM_F+school_data.SCH_ENR_HP_M+school_data.SCH_ENR_HP_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
# (school_data.SCH_ENR_AS_M+school_data.SCH_ENR_AS_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
# (school_data.SCH_ENR_BL_M+school_data.SCH_ENR_BL_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
# (school_data.SCH_ENR_WH_M+school_data.SCH_ENR_WH_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
# (school_data.SCH_ENR_TR_M+school_data.SCH_ENR_TR_F)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
#
# #### Corperal Punishment:
# (school_data.SCH_CORPINSTANCES_WODIS+school_data.SCH_CORPINSTANCES_WDIS)/(school_data.TOT_ENR_M + school.data.TOT_ENR_F)
#
# #### School Size
# (school_data.TOT_ENR_M + school.data.TOT_ENR_F)
#
# #### Suspensions
# SCH_OOSINSTANCES_WODIS
# SCH_OOSINSTANCES_IDEA
# SCH_OOSINSTANCES_504
#
# #### Expulsions
# TOT_DISCWODIS_EXPZT_M
# TOT_DISCWODIS_EXPZT_F
# SCH_DISCWODIS_EXPZT_LEP_M
# SCH_DISCWODIS_EXPZT_LEP_F

# %%
S
SCH_SAL_TOTPERS_WFED
