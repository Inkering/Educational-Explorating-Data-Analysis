# %% [markdown]
# # Preliminary Exploration Notebook

# %%
import pandas as pd
import numpy as np

# %%
school_data = pd.read_csv("data/CRDC 2015-16 School Data.csv", encoding = "ISO-8859-1")
school_layout = pd.read_csv("data/CRDC 2015-16 School Data Record Layout.csv", encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,6,23,24,25,30,31,1828) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
school_data.head()
# Out:
#   LEA_STATE LEA_STATE_NAME   LEAID                LEA_NAME  SCHID  \
# 0        AL        ALABAMA  100002  Alabama Youth Services   1705
# 1        AL        ALABAMA  100002  Alabama Youth Services   1706
# 2        AL        ALABAMA  100002  Alabama Youth Services   1876
# 3        AL        ALABAMA  100002  Alabama Youth Services  99995
# 4        AL        ALABAMA  100005        Albertville City    870
#
#                         SCH_NAME     COMBOKEY   JJ SCH_GRADE_PS SCH_GRADE_KG  \
# 0  Wallace Sch - Mt Meigs Campus  10000201705  Yes           No           No
# 1      McNeel Sch - Vacca Campus  10000201706  Yes           No           No
# 2         Alabama Youth Services  10000201876   No           No           No
# 3                 AUTAUGA CAMPUS  10000299995  Yes           No           No
# 4      Albertville Middle School  10000500870   No           No           No
#
#         ...        SCH_FTESERVICES_PSY SCH_FTESERVICES_SOC SCH_JJTYPE  \
# 0       ...                        2.0                 0.0         -7
# 1       ...                        1.0                 0.0         -7
# 2       ...                        0.0                 0.0         -9
# 3       ...                        0.0                 0.0         -7
# 4       ...                        0.0                 0.0         -9
#
#   SCH_JJSYDAYS SCH_JJHOURS SCH_JJPART_LT15 SCH_JJPART_15T30 SCH_JJPART_31T90  \
# 0           -7          -7              -7               -7               -7
# 1           -7          -7              -7               -7               -7
# 2           -9          -9              -9               -9               -9
# 3           -7          -7              -7               -7               -7
# 4           -9          -9              -9               -9               -9
#
#   SCH_JJPART_91T180 SCH_JJPART_OV180
# 0                -7               -7
# 1                -7               -7
# 2                -9               -9
# 3                -7               -7
# 4                -9               -9
#
# [5 rows x 1836 columns]

# %%
school_data.shape
# Out:
# (96360, 1836)

# %%
school_layout[school_layout["Field_Name"] == "SCH_JJHOURS"]["Field_Description"]
# Out:
# 1830    Justice Facility Educational Program Hours per...
# Name: Field_Description, dtype: object

# %%
school_layout
# Out:
#       Order Excel_Column_Finder             Field_Name  \
# 0         1                   A              LEA_STATE
# 1         2                   B         LEA_STATE_NAME
# 2         3                   C                  LEAID
# 3         4                   D               LEA_NAME
# 4         5                   E                  SCHID
# 5         6                   F               SCH_NAME
# 6         7                   G               COMBOKEY
# 7         8                   H                     JJ
# 8         9                   I           SCH_GRADE_PS
# 9        10                   J           SCH_GRADE_KG
# 10       11                   K          SCH_GRADE_G01
# 11       12                   L          SCH_GRADE_G02
# 12       13                   M          SCH_GRADE_G03
# 13       14                   N          SCH_GRADE_G04
# 14       15                   O          SCH_GRADE_G05
# 15       16                   P          SCH_GRADE_G06
# 16       17                   Q          SCH_GRADE_G07
# 17       18                   R          SCH_GRADE_G08
# 18       19                   S          SCH_GRADE_G09
# 19       20                   T          SCH_GRADE_G10
# 20       21                   U          SCH_GRADE_G11
# 21       22                   V          SCH_GRADE_G12
# 22       23                   W           SCH_GRADE_UG
# 23       24                   X        SCH_UGDETAIL_ES
# 24       25                   Y        SCH_UGDETAIL_MS
# 25       26                   Z        SCH_UGDETAIL_HS
# 26       27                  AA        SCH_STATUS_SPED
# 27       28                  AB      SCH_STATUS_MAGNET
# 28       29                  AC     SCH_STATUS_CHARTER
# 29       30                  AD         SCH_STATUS_ALT
# ...     ...                 ...                    ...
# 1806   1807                 BQM       SCH_FTE_AID_WFED
# 1807   1808                 BQN       SCH_SAL_AID_WFED
# 1808   1809                 BQO       SCH_FTE_SUP_WFED
# 1809   1810                 BQP       SCH_SAL_SUP_WFED
# 1810   1811                 BQQ       SCH_FTE_ADM_WFED
# 1811   1812                 BQR       SCH_SAL_ADM_WFED
# 1812   1813                 BQS   SCH_SAL_TOTPERS_WFED
# 1813   1814                 BQT           SCH_NPE_WFED
# 1814   1815                 BQU       SCH_FTETEACH_TOT
# 1815   1816                 BQV      SCH_FTETEACH_CERT
# 1816   1817                 BQW   SCH_FTETEACH_NOTCERT
# 1817   1818                 BQX        SCH_FTETEACH_FY
# 1818   1819                 BQY        SCH_FTETEACH_SY
# 1819   1820                 BQZ  SCH_TEACHERS_CURR_TOT
# 1820   1821                 BRA  SCH_TEACHERS_PREV_TOT
# 1821   1822                 BRB      SCH_FTECOUNSELORS
# 1822   1823                 BRC    SCH_FTETEACH_ABSENT
# 1823   1824                 BRD    SCH_FTESECURITY_LEO
# 1824   1825                 BRE    SCH_FTESECURITY_GUA
# 1825   1826                 BRF    SCH_FTESERVICES_NUR
# 1826   1827                 BRG    SCH_FTESERVICES_PSY
# 1827   1828                 BRH    SCH_FTESERVICES_SOC
# 1828   1829                 BRI             SCH_JJTYPE
# 1829   1830                 BRJ           SCH_JJSYDAYS
# 1830   1831                 BRK            SCH_JJHOURS
# 1831   1832                 BRL        SCH_JJPART_LT15
# 1832   1833                 BRM       SCH_JJPART_15T30
# 1833   1834                 BRN       SCH_JJPART_31T90
# 1834   1835                 BRO      SCH_JJPART_91T180
# 1835   1836                 BRP       SCH_JJPART_OV180
#
#                                       Field_Description  \
# 0                           District State Abbreviation
# 1                                   District State Name
# 2            7 Digit LEAID District Identification Code
# 3                                         District Name
# 4                    5 Digit School Identification Code
# 5                                           School Name
# 6     7 Digit LEAID District Identification Code+5 D...
# 7     Juvenile Justice Facility: "Yes" indicates a l...
# 8              Grades with Students Enrolled: Preschool
# 9           Grades with Students Enrolled: Kindergarten
# 10               Grades with Students Enrolled: Grade 1
# 11               Grades with Students Enrolled: Grade 2
# 12               Grades with Students Enrolled: Grade 3
# 13               Grades with Students Enrolled: Grade 4
# 14               Grades with Students Enrolled: Grade 5
# 15               Grades with Students Enrolled: Grade 6
# 16               Grades with Students Enrolled: Grade 7
# 17               Grades with Students Enrolled: Grade 8
# 18               Grades with Students Enrolled: Grade 9
# 19              Grades with Students Enrolled: Grade 10
# 20              Grades with Students Enrolled: Grade 11
# 21              Grades with Students Enrolled: Grade 12
# 22              Grades with Students Enrolled: Ungraded
# 23      Ungraded Detail: Elementary school age students
# 24          Ungraded Detail: Middle school age students
# 25            Ungraded Detail: High school age students
# 26     School Characteristics: Special education school
# 27    School Characteristics: Magnet school or schoo...
# 28               School Characteristics: Charter school
# 29           School Characteristics: Alternative school
# ...                                                 ...
# 1806  Full-time Equivalency Count of Instructional A...
# 1807  Salary Expenditures for Instructional Aides Fu...
# 1808  Full-time Equivalency Count of Support Service...
# 1809  Salary Expenditures for Support Services Staff...
# 1810  Full-time Equivalency Count of School Administ...
# 1811  Salary Expenditures for  School Administration...
# 1812  Salary Expenditures for Total Personnel (instr...
# 1813  Amount of Non-Personnel Expenditures Associate...
# 1814                              Total FTE of Teachers
# 1815           Number of FTE teachers who are certified
# 1816       Number of FTE teachers who are not certified
# 1817  Number of FTE teachers in their first year of ...
# 1818  Number of FTE teachers in their second year of...
# 1819             Number of current school year teachers
# 1820            Number of previous school year teachers
# 1821                    Number of FTE school counselors
# 1822  Number of FTE teachers who were absent more th...
# 1823       Number of FTE sworn law enforcement officers
# 1824                      Number of FTE security guards
# 1825                               Number of FTE nurses
# 1826                        Number of FTE psychologists
# 1827                       Number of FTE social workers
# 1828                              Justice Facility Type
# 1829    Days in Regular School Year at Justice Facility
# 1830  Justice Facility Educational Program Hours per...
# 1831  Students who participated in credit granting e...
# 1832  Students who participated in credit granting e...
# 1833  Students who participated in credit granting e...
# 1834  Students who participated in credit granting e...
# 1835  Students who participated in credit granting e...
#
#                       Module
# 0             Identification
# 1             Identification
# 2             Identification
# 3             Identification
# 4             Identification
# 5             Identification
# 6             Identification
# 7             Identification
# 8     School Characteristics
# 9     School Characteristics
# 10    School Characteristics
# 11    School Characteristics
# 12    School Characteristics
# 13    School Characteristics
# 14    School Characteristics
# 15    School Characteristics
# 16    School Characteristics
# 17    School Characteristics
# 18    School Characteristics
# 19    School Characteristics
# 20    School Characteristics
# 21    School Characteristics
# 22    School Characteristics
# 23    School Characteristics
# 24    School Characteristics
# 25    School Characteristics
# 26    School Characteristics
# 27    School Characteristics
# 28    School Characteristics
# 29    School Characteristics
# ...                      ...
# 1806     School Expenditures
# 1807     School Expenditures
# 1808     School Expenditures
# 1809     School Expenditures
# 1810     School Expenditures
# 1811     School Expenditures
# 1812     School Expenditures
# 1813     School Expenditures
# 1814          School Support
# 1815          School Support
# 1816          School Support
# 1817          School Support
# 1818          School Support
# 1819          School Support
# 1820          School Support
# 1821          School Support
# 1822          School Support
# 1823          School Support
# 1824          School Support
# 1825          School Support
# 1826          School Support
# 1827          School Support
# 1828        Justice Facility
# 1829        Justice Facility
# 1830        Justice Facility
# 1831        Justice Facility
# 1832        Justice Facility
# 1833        Justice Facility
# 1834        Justice Facility
# 1835        Justice Facility
#
# [1836 rows x 5 columns]

# %% [markdown]
# **Note:**  For cell values in the school data frame, negative numbers have special meanings as follows:
# -2 means small cell values,
# -5 means there is an action plan (next survey),
# -6 Force Certified (missing data),
# -7 System error,
# -8 EDFacts Missing Data,
# -9 means not applicable / skipped

# %%
# print(len(school_data[school_data["LEA_STATE_NAME"] == "CALIFORNIA"]))
nul_vals = [-2,-5,-6,-7,-8,-9, '-2', '-5', '-6','-7','-8','-9']
for (columnName, columnData) in school_data.iteritems():
     print(round(len(school_data[columnName][school_data[columnName].isin(nul_vals)])/school_data.shape[0], 3), columnName);
# Out:
# 0.0 LEA_STATE
# 0.0 LEA_STATE_NAME
# 0.0 LEAID
# 0.0 LEA_NAME
# 0.0 SCHID
# 0.0 SCH_NAME
# 0.0 COMBOKEY
# 0.0 JJ
# 0.0 SCH_GRADE_PS
# 0.0 SCH_GRADE_KG
# 0.0 SCH_GRADE_G01
# 0.0 SCH_GRADE_G02
# 0.0 SCH_GRADE_G03
# 0.0 SCH_GRADE_G04
# 0.0 SCH_GRADE_G05
# 0.0 SCH_GRADE_G06
# 0.0 SCH_GRADE_G07
# 0.0 SCH_GRADE_G08
# 0.0 SCH_GRADE_G09
# 0.0 SCH_GRADE_G10
# 0.0 SCH_GRADE_G11
# 0.0 SCH_GRADE_G12
# 0.0 SCH_GRADE_UG
# 0.955 SCH_UGDETAIL_ES
# 0.955 SCH_UGDETAIL_MS
# 0.955 SCH_UGDETAIL_HS
# 0.0 SCH_STATUS_SPED
# 0.0 SCH_STATUS_MAGNET
# 0.0 SCH_STATUS_CHARTER
# 0.0 SCH_STATUS_ALT
# 0.962 SCH_MAGNETDETAIL
# 0.966 SCH_ALTFOCUS
# 0.69 SCH_PSENR_NONIDEA_A3
# 0.69 SCH_PSENR_NONIDEA_A4
# 0.69 SCH_PSENR_NONIDEA_A5
# 0.69 SCH_PSENR_HI_M
# 0.69 SCH_PSENR_HI_F
# 0.69 SCH_PSENR_AM_M
# 0.69 SCH_PSENR_AM_F
# 0.69 SCH_PSENR_AS_M
# 0.69 SCH_PSENR_AS_F
# 0.69 SCH_PSENR_HP_M
# 0.69 SCH_PSENR_HP_F
# 0.69 SCH_PSENR_BL_M
# 0.69 SCH_PSENR_BL_F
# 0.69 SCH_PSENR_WH_M
# 0.69 SCH_PSENR_WH_F
# 0.69 SCH_PSENR_TR_M
# 0.69 SCH_PSENR_TR_F
# 0.69 TOT_PSENR_M
# 0.69 TOT_PSENR_F
# 0.69 SCH_PSENR_LEP_M
# 0.69 SCH_PSENR_LEP_F
# 0.69 SCH_PSENR_IDEA_M
# 0.69 SCH_PSENR_IDEA_F
# 0.0 SCH_ENR_HI_M
# 0.0 SCH_ENR_HI_F
# 0.0 SCH_ENR_AM_M
# 0.0 SCH_ENR_AM_F
# 0.0 SCH_ENR_AS_M
# 0.0 SCH_ENR_AS_F
# 0.0 SCH_ENR_HP_M
# 0.0 SCH_ENR_HP_F
# 0.0 SCH_ENR_BL_M
# 0.0 SCH_ENR_BL_F
# 0.0 SCH_ENR_WH_M
# 0.0 SCH_ENR_WH_F
# 0.0 SCH_ENR_TR_M
# 0.0 SCH_ENR_TR_F
# 0.0 TOT_ENR_M
# 0.0 TOT_ENR_F
# 0.0 SCH_ENR_LEP_M
# 0.0 SCH_ENR_LEP_F
# 0.0 SCH_ENR_504_M
# 0.0 SCH_ENR_504_F
# 0.062 SCH_ENR_IDEA_M
# 0.1 SCH_ENR_IDEA_F
# 0.0 SCH_LEPENR_HI_M
# 0.0 SCH_LEPENR_HI_F
# 0.0 SCH_LEPENR_AM_M
# 0.0 SCH_LEPENR_AM_F
# 0.0 SCH_LEPENR_AS_M
# 0.0 SCH_LEPENR_AS_F
# 0.0 SCH_LEPENR_HP_M
# 0.0 SCH_LEPENR_HP_F
# 0.0 SCH_LEPENR_BL_M
# 0.0 SCH_LEPENR_BL_F
# 0.0 SCH_LEPENR_WH_M
# 0.0 SCH_LEPENR_WH_F
# 0.0 SCH_LEPENR_TR_M
# 0.0 SCH_LEPENR_TR_F
# 0.0 TOT_LEPENR_M
# 0.0 TOT_LEPENR_F
# 0.0 SCH_LEPPROGENR_HI_M
# 0.0 SCH_LEPPROGENR_HI_F
# 0.0 SCH_LEPPROGENR_AM_M
# 0.0 SCH_LEPPROGENR_AM_F
# 0.0 SCH_LEPPROGENR_AS_M
# 0.0 SCH_LEPPROGENR_AS_F
# 0.0 SCH_LEPPROGENR_HP_M
# 0.0 SCH_LEPPROGENR_HP_F
# 0.0 SCH_LEPPROGENR_BL_M
# 0.0 SCH_LEPPROGENR_BL_F
# 0.0 SCH_LEPPROGENR_WH_M
# 0.0 SCH_LEPPROGENR_WH_F
# 0.0 SCH_LEPPROGENR_TR_M
# 0.0 SCH_LEPPROGENR_TR_F
# 0.0 TOT_LEPPROGENR_M
# 0.0 TOT_LEPPROGENR_F
# 0.0 SCH_LEPPROGENR_IDEA_M
# 0.0 SCH_LEPPROGENR_IDEA_F
# 0.449 SCH_IDEAENR_HI_M
# 0.576 SCH_IDEAENR_HI_F
# 0.954 SCH_IDEAENR_AM_M
# 0.973 SCH_IDEAENR_AM_F
# 0.88 SCH_IDEAENR_AS_M
# 0.946 SCH_IDEAENR_AS_F
# 0.992 SCH_IDEAENR_HP_M
# 0.996 SCH_IDEAENR_HP_F
# 0.553 SCH_IDEAENR_BL_M
# 0.666 SCH_IDEAENR_BL_F
# 0.208 SCH_IDEAENR_WH_M
# 0.298 SCH_IDEAENR_WH_F
# 0.79 SCH_IDEAENR_TR_M
# 0.909 SCH_IDEAENR_TR_F
# 0.072 TOT_IDEAENR_M
# 0.12 TOT_IDEAENR_F
# 0.673 SCH_IDEAENR_LEP_M
# 0.771 SCH_IDEAENR_LEP_F
# 0.0 SCH_504ENR_HI_M
# 0.0 SCH_504ENR_HI_F
# 0.0 SCH_504ENR_AM_M
# 0.0 SCH_504ENR_AM_F
# 0.0 SCH_504ENR_AS_M
# 0.0 SCH_504ENR_AS_F
# 0.0 SCH_504ENR_HP_M
# 0.0 SCH_504ENR_HP_F
# 0.0 SCH_504ENR_BL_M
# 0.0 SCH_504ENR_BL_F
# 0.0 SCH_504ENR_WH_M
# 0.0 SCH_504ENR_WH_F
# 0.0 SCH_504ENR_TR_M
# 0.0 SCH_504ENR_TR_F
# 0.0 TOT_504ENR_M
# 0.0 TOT_504ENR_F
# 0.0 SCH_504ENR_LEP_M
# 0.0 SCH_504ENR_LEP_F
# 0.0 SCH_GT_IND
# 0.424 SCH_GTENR_HI_M
# 0.424 SCH_GTENR_HI_F
# 0.424 SCH_GTENR_AM_M
# 0.424 SCH_GTENR_AM_F
# 0.424 SCH_GTENR_AS_M
# 0.424 SCH_GTENR_AS_F
# 0.424 SCH_GTENR_HP_M
# 0.424 SCH_GTENR_HP_F
# 0.424 SCH_GTENR_BL_M
# 0.424 SCH_GTENR_BL_F
# 0.424 SCH_GTENR_WH_M
# 0.424 SCH_GTENR_WH_F
# 0.424 SCH_GTENR_TR_M
# 0.424 SCH_GTENR_TR_F
# 0.424 TOT_GTENR_M
# 0.424 TOT_GTENR_F
# 0.424 SCH_GTENR_LEP_M
# 0.424 SCH_GTENR_LEP_F
# 0.424 SCH_GTENR_IDEA_M
# 0.424 SCH_GTENR_IDEA_F
# 0.726 SCH_DUAL_IND
# 0.85 SCH_DUALENR_HI_M
# 0.85 SCH_DUALENR_HI_F
# 0.85 SCH_DUALENR_AM_M
# 0.85 SCH_DUALENR_AM_F
# 0.85 SCH_DUALENR_AS_M
# 0.85 SCH_DUALENR_AS_F
# 0.85 SCH_DUALENR_HP_M
# 0.85 SCH_DUALENR_HP_F
# 0.85 SCH_DUALENR_BL_M
# 0.85 SCH_DUALENR_BL_F
# 0.85 SCH_DUALENR_WH_M
# 0.85 SCH_DUALENR_WH_F
# 0.85 SCH_DUALENR_TR_M
# 0.85 SCH_DUALENR_TR_F
# 0.85 TOT_DUAL_M
# 0.85 TOT_DUAL_F
# 0.85 SCH_DUALENR_LEP_M
# 0.85 SCH_DUALENR_LEP_F
# 0.85 SCH_DUALENR_IDEA_M
# 0.85 SCH_DUALENR_IDEA_F
# 0.726 SCH_CREDITRECOVERY_IND
# 0.838 SCH_CREDITRECOVERYENR
# 0.68 SCH_ALGCLASSES_GS0708
# 0.81 SCH_ALGCERT_GS0708
# 0.813 SCH_ALGENR_G07_IND
# 0.932 SCH_ALGENR_G07
# 0.811 SCH_ALGENR_G08_IND
# 0.819 SCH_ALGENR_G08_HI_M
# 0.819 SCH_ALGENR_G08_HI_F
# 0.819 SCH_ALGENR_G08_AM_M
# 0.819 SCH_ALGENR_G08_AM_F
# 0.819 SCH_ALGENR_G08_AS_M
# 0.819 SCH_ALGENR_G08_AS_F
# 0.819 SCH_ALGENR_G08_HP_M
# 0.819 SCH_ALGENR_G08_HP_F
# 0.819 SCH_ALGENR_G08_BL_M
# 0.819 SCH_ALGENR_G08_BL_F
# 0.819 SCH_ALGENR_G08_WH_M
# 0.819 SCH_ALGENR_G08_WH_F
# 0.819 SCH_ALGENR_G08_TR_M
# 0.819 SCH_ALGENR_G08_TR_F
# 0.819 TOT_ALGENR_G08_M
# 0.819 TOT_ALGENR_G08_F
# 0.819 SCH_ALGENR_G08_LEP_M
# 0.819 SCH_ALGENR_G08_LEP_F
# 0.819 SCH_ALGENR_G08_IDEA_M
# 0.819 SCH_ALGENR_G08_IDEA_F
# 0.726 SCH_MATHCLASSES_ALG
# 0.765 SCH_MATHCERT_ALG
# 0.767 SCH_ALGENR_GS0910_HI_M
# 0.767 SCH_ALGENR_GS0910_HI_F
# 0.767 SCH_ALGENR_GS0910_AM_M
# 0.767 SCH_ALGENR_GS0910_AM_F
# 0.767 SCH_ALGENR_GS0910_AS_M
# 0.767 SCH_ALGENR_GS0910_AS_F
# 0.767 SCH_ALGENR_GS0910_HP_M
# 0.767 SCH_ALGENR_GS0910_HP_F
# 0.767 SCH_ALGENR_GS0910_BL_M
# 0.767 SCH_ALGENR_GS0910_BL_F
# 0.767 SCH_ALGENR_GS0910_WH_M
# 0.767 SCH_ALGENR_GS0910_WH_F
# 0.767 SCH_ALGENR_GS0910_TR_M
# 0.767 SCH_ALGENR_GS0910_TR_F
# 0.767 TOT_ALGENR_GS0910_M
# 0.767 TOT_ALGENR_GS0910_F
# 0.767 SCH_ALGENR_GS0910_LEP_M
# 0.767 SCH_ALGENR_GS0910_LEP_F
# 0.767 SCH_ALGENR_GS0910_IDEA_M
# 0.767 SCH_ALGENR_GS0910_IDEA_F
# 0.772 SCH_ALGENR_GS1112_HI_M
# 0.772 SCH_ALGENR_GS1112_HI_F
# 0.772 SCH_ALGENR_GS1112_AM_M
# 0.772 SCH_ALGENR_GS1112_AM_F
# 0.772 SCH_ALGENR_GS1112_AS_M
# 0.772 SCH_ALGENR_GS1112_AS_F
# 0.772 SCH_ALGENR_GS1112_HP_M
# 0.772 SCH_ALGENR_GS1112_HP_F
# 0.772 SCH_ALGENR_GS1112_BL_M
# 0.772 SCH_ALGENR_GS1112_BL_F
# 0.772 SCH_ALGENR_GS1112_WH_M
# 0.772 SCH_ALGENR_GS1112_WH_F
# 0.772 SCH_ALGENR_GS1112_TR_M
# 0.772 SCH_ALGENR_GS1112_TR_F
# 0.772 TOT_ALGENR_GS1112_M
# 0.772 TOT_ALGENR_GS1112_F
# 0.772 SCH_ALGENR_GS1112_LEP_M
# 0.772 SCH_ALGENR_GS1112_LEP_F
# 0.772 SCH_ALGENR_GS1112_IDEA_M
# 0.772 SCH_ALGENR_GS1112_IDEA_F
# 0.959 SCH_ALGPASS_G07
# 0.948 SCH_ALGPASS_G08_HI_M
# 0.945 SCH_ALGPASS_G08_HI_F
# 0.998 SCH_ALGPASS_G08_AM_M
# 0.998 SCH_ALGPASS_G08_AM_F
# 0.972 SCH_ALGPASS_G08_AS_M
# 0.969 SCH_ALGPASS_G08_AS_F
# 0.999 SCH_ALGPASS_G08_HP_M
# 0.999 SCH_ALGPASS_G08_HP_F
# 0.968 SCH_ALGPASS_G08_BL_M
# 0.962 SCH_ALGPASS_G08_BL_F
# 0.88 SCH_ALGPASS_G08_WH_M
# 0.878 SCH_ALGPASS_G08_WH_F
# 0.987 SCH_ALGPASS_G08_TR_M
# 0.984 SCH_ALGPASS_G08_TR_F
# 0.857 TOT_ALGPASS_G08_M
# 0.855 TOT_ALGPASS_G08_F
# 0.991 SCH_ALGPASS_G08_LEP_M
# 0.992 SCH_ALGPASS_G08_LEP_F
# 0.985 SCH_ALGPASS_G08_IDEA_M
# 0.992 SCH_ALGPASS_G08_IDEA_F
# 0.898 SCH_ALGPASS_GS0910_HI_M
# 0.9 SCH_ALGPASS_GS0910_HI_F
# 0.989 SCH_ALGPASS_GS0910_AM_M
# 0.989 SCH_ALGPASS_GS0910_AM_F
# 0.965 SCH_ALGPASS_GS0910_AS_M
# 0.966 SCH_ALGPASS_GS0910_AS_F
# 0.997 SCH_ALGPASS_GS0910_HP_M
# 0.997 SCH_ALGPASS_GS0910_HP_F
# 0.912 SCH_ALGPASS_GS0910_BL_M
# 0.915 SCH_ALGPASS_GS0910_BL_F
# 0.839 SCH_ALGPASS_GS0910_WH_M
# 0.844 SCH_ALGPASS_GS0910_WH_F
# 0.96 SCH_ALGPASS_GS0910_TR_M
# 0.96 SCH_ALGPASS_GS0910_TR_F
# 0.809 TOT_ALGPASS_GS0910_M
# 0.814 TOT_ALGPASS_GS0910_F
# 0.945 SCH_ALGPASS_GS0910_LEP_M
# 0.949 SCH_ALGPASS_GS0910_LEP_F
# 0.88 SCH_ALGPASS_GS0910_IDEA_M
# 0.905 SCH_ALGPASS_GS0910_IDEA_F
# 0.977 SCH_ALGPASS_GS1112_HI_M
# 0.981 SCH_ALGPASS_GS1112_HI_F
# 0.999 SCH_ALGPASS_GS1112_AM_M
# 0.999 SCH_ALGPASS_GS1112_AM_F
# 0.998 SCH_ALGPASS_GS1112_AS_M
# 0.999 SCH_ALGPASS_GS1112_AS_F
# 1.0 SCH_ALGPASS_GS1112_HP_M
# 1.0 SCH_ALGPASS_GS1112_HP_F
# 0.984 SCH_ALGPASS_GS1112_BL_M
# 0.988 SCH_ALGPASS_GS1112_BL_F
# 0.967 SCH_ALGPASS_GS1112_WH_M
# 0.977 SCH_ALGPASS_GS1112_WH_F
# 0.998 SCH_ALGPASS_GS1112_TR_M
# 0.999 SCH_ALGPASS_GS1112_TR_F
# 0.945 TOT_ALGPASS_GS1112_M
# 0.958 TOT_ALGPASS_GS1112_F
# 0.989 SCH_ALGPASS_GS1112_LEP_M
# 0.991 SCH_ALGPASS_GS1112_LEP_F
# 0.977 SCH_ALGPASS_GS1112_IDEA_M
# 0.988 SCH_ALGPASS_GS1112_IDEA_F
# 0.688 SCH_GEOMENR_G08_IND
# 0.942 SCH_GEOMENR_G08
# 0.769 SCH_MATHCERT_GEOM
# 0.726 SCH_MATHCLASSES_GEOM
# 0.77 SCH_MATHENR_GEOM_HI_M
# 0.77 SCH_MATHENR_GEOM_HI_F
# 0.77 SCH_MATHENR_GEOM_AM_M
# 0.77 SCH_MATHENR_GEOM_AM_F
# 0.77 SCH_MATHENR_GEOM_AS_M
# 0.77 SCH_MATHENR_GEOM_AS_F
# 0.77 SCH_MATHENR_GEOM_HP_M
# 0.77 SCH_MATHENR_GEOM_HP_F
# 0.77 SCH_MATHENR_GEOM_BL_M
# 0.77 SCH_MATHENR_GEOM_BL_F
# 0.77 SCH_MATHENR_GEOM_WH_M
# 0.77 SCH_MATHENR_GEOM_WH_F
# 0.77 SCH_MATHENR_GEOM_TR_M
# 0.77 SCH_MATHENR_GEOM_TR_F
# 0.77 TOT_GEOM_M
# 0.77 TOT_GEOM_F
# 0.77 SCH_MATHENR_GEOM_LEP_M
# 0.77 SCH_MATHENR_GEOM_LEP_F
# 0.77 SCH_MATHENR_GEOM_IDEA_M
# 0.77 SCH_MATHENR_GEOM_IDEA_F
# 0.726 SCH_MATHCLASSES_ALG2
# 0.781 SCH_MATHCERT_ALG2
# 0.781 SCH_MATHENR_ALG2_HI_M
# 0.781 SCH_MATHENR_ALG2_HI_F
# 0.781 SCH_MATHENR_ALG2_AM_M
# 0.781 SCH_MATHENR_ALG2_AM_F
# 0.781 SCH_MATHENR_ALG2_AS_M
# 0.781 SCH_MATHENR_ALG2_AS_F
# 0.781 SCH_MATHENR_ALG2_HP_M
# 0.781 SCH_MATHENR_ALG2_HP_F
# 0.781 SCH_MATHENR_ALG2_BL_M
# 0.781 SCH_MATHENR_ALG2_BL_F
# 0.781 SCH_MATHENR_ALG2_WH_M
# 0.781 SCH_MATHENR_ALG2_WH_F
# 0.781 SCH_MATHENR_ALG2_TR_M
# 0.781 SCH_MATHENR_ALG2_TR_F
# 0.781 TOT_MATHENR_ALG2_M
# 0.781 TOT_MATHENR_ALG2_F
# 0.781 SCH_MATHENR_ALG2_LEP_M
# 0.781 SCH_MATHENR_ALG2_LEP_F
# 0.781 SCH_MATHENR_ALG2_IDEA_M
# 0.781 SCH_MATHENR_ALG2_IDEA_F
# 0.726 SCH_MATHCLASSES_CALC
# 0.862 SCH_MATHCERT_CALC
# 0.862 SCH_MATHENR_CALC_HI_M
# 0.862 SCH_MATHENR_CALC_HI_F
# 0.862 SCH_MATHENR_CALC_AM_M
# 0.862 SCH_MATHENR_CALC_AM_F
# 0.862 SCH_MATHENR_CALC_AS_M
# 0.862 SCH_MATHENR_CALC_AS_F
# 0.862 SCH_MATHENR_CALC_HP_M
# 0.862 SCH_MATHENR_CALC_HP_F
# 0.862 SCH_MATHENR_CALC_BL_M
# 0.862 SCH_MATHENR_CALC_BL_F
# 0.862 SCH_MATHENR_CALC_WH_M
# 0.862 SCH_MATHENR_CALC_WH_F
# 0.862 SCH_MATHENR_CALC_TR_M
# 0.862 SCH_MATHENR_CALC_TR_F
# 0.862 TOT_MATHENR_CALC_M
# 0.862 TOT_MATHENR_CALC_F
# 0.862 SCH_MATHENR_CALC_LEP_M
# 0.862 SCH_MATHENR_CALC_LEP_F
# 0.862 SCH_MATHENR_CALC_IDEA_M
# 0.862 SCH_MATHENR_CALC_IDEA_F
# 0.726 SCH_MATHCLASSES_ADVM
# 0.822 SCH_MATHCERT_ADVM
# 0.822 SCH_MATHENR_ADVM_HI_M
# 0.822 SCH_MATHENR_ADVM_HI_F
# 0.822 SCH_MATHENR_ADVM_AM_M
# 0.822 SCH_MATHENR_ADVM_AM_F
# 0.822 SCH_MATHENR_ADVM_AS_M
# 0.822 SCH_MATHENR_ADVM_AS_F
# 0.822 SCH_MATHENR_ADVM_HP_M
# 0.822 SCH_MATHENR_ADVM_HP_F
# 0.822 SCH_MATHENR_ADVM_BL_M
# 0.822 SCH_MATHENR_ADVM_BL_F
# 0.822 SCH_MATHENR_ADVM_WH_M
# 0.822 SCH_MATHENR_ADVM_WH_F
# 0.822 SCH_MATHENR_ADVM_TR_M
# 0.822 SCH_MATHENR_ADVM_TR_F
# 0.822 TOT_MATHENR_ADVM_M
# 0.822 TOT_MATHENR_ADVM_F
# 0.822 SCH_MATHENR_ADVM_LEP_M
# 0.822 SCH_MATHENR_ADVM_LEP_F
# 0.822 SCH_MATHENR_ADVM_IDEA_M
# 0.822 SCH_MATHENR_ADVM_IDEA_F
# 0.726 SCH_SCICLASSES_BIOL
# 0.765 SCH_SCICCERT_BIOL
# 0.765 SCH_SCIENR_BIOL_HI_M
# 0.765 SCH_SCIENR_BIOL_HI_F
# 0.765 SCH_SCIENR_BIOL_AM_M
# 0.765 SCH_SCIENR_BIOL_AM_F
# 0.765 SCH_SCIENR_BIOL_AS_M
# 0.765 SCH_SCIENR_BIOL_AS_F
# 0.765 SCH_SCIENR_BIOL_HP_M
# 0.765 SCH_SCIENR_BIOL_HP_F
# 0.765 SCH_SCIENR_BIOL_BL_M
# 0.765 SCH_SCIENR_BIOL_BL_F
# 0.765 SCH_SCIENR_BIOL_WH_M
# 0.765 SCH_SCIENR_BIOL_WH_F
# 0.765 SCH_SCIENR_BIOL_TR_M
# 0.765 SCH_SCIENR_BIOL_TR_F
# 0.765 TOT_SCIENR_BIOL_M
# 0.765 TOT_SCIENR_BIOL_F
# 0.765 SCH_SCIENR_BIOL_LEP_M
# 0.765 SCH_SCIENR_BIOL_LEP_F
# 0.765 SCH_SCIENR_BIOL_IDEA_M
# 0.765 SCH_SCIENR_BIOL_IDEA_F
# 0.726 SCH_SCICLASSES_CHEM
# 0.799 SCH_SCICCERT_CHEM
# 0.799 SCH_SCIENR_CHEM_HI_M
# 0.799 SCH_SCIENR_CHEM_HI_F
# 0.799 SCH_SCIENR_CHEM_AM_M
# 0.799 SCH_SCIENR_CHEM_AM_F
# 0.799 SCH_SCIENR_CHEM_AS_M
# 0.799 SCH_SCIENR_CHEM_AS_F
# 0.799 SCH_SCIENR_CHEM_HP_M
# 0.799 SCH_SCIENR_CHEM_HP_F
# 0.799 SCH_SCIENR_CHEM_BL_M
# 0.799 SCH_SCIENR_CHEM_BL_F
# 0.799 SCH_SCIENR_CHEM_WH_M
# 0.799 SCH_SCIENR_CHEM_WH_F
# 0.799 SCH_SCIENR_CHEM_TR_M
# 0.799 SCH_SCIENR_CHEM_TR_F
# 0.799 TOT_SCIENR_CHEM_M
# 0.799 TOT_SCIENR_CHEM_F
# 0.799 SCH_SCIENR_CHEM_LEP_M
# 0.799 SCH_SCIENR_CHEM_LEP_F
# 0.799 SCH_SCIENR_CHEM_IDEA_M
# 0.799 SCH_SCIENR_CHEM_IDEA_F
# 0.726 SCH_SCICLASSES_PHYS
# 0.834 SCH_SCICCERT_PHYS
# 0.834 SCH_SCIENR_PHYS_HI_M
# 0.834 SCH_SCIENR_PHYS_HI_F
# 0.834 SCH_SCIENR_PHYS_AM_M
# 0.834 SCH_SCIENR_PHYS_AM_F
# 0.834 SCH_SCIENR_PHYS_AS_M
# 0.834 SCH_SCIENR_PHYS_AS_F
# 0.834 SCH_SCIENR_PHYS_HP_M
# 0.834 SCH_SCIENR_PHYS_HP_F
# 0.834 SCH_SCIENR_PHYS_BL_M
# 0.834 SCH_SCIENR_PHYS_BL_F
# 0.834 SCH_SCIENR_PHYS_WH_M
# 0.834 SCH_SCIENR_PHYS_WH_F
# 0.834 SCH_SCIENR_PHYS_TR_M
# 0.834 SCH_SCIENR_PHYS_TR_F
# 0.834 TOT_SCIENR_PHYS_M
# 0.834 TOT_SCIENR_PHYS_F
# 0.834 SCH_SCIENR_PHYS_LEP_M
# 0.834 SCH_SCIENR_PHYS_LEP_F
# 0.834 SCH_SCIENR_PHYS_IDEA_M
# 0.834 SCH_SCIENR_PHYS_IDEA_F
# 0.029 SCH_SSCLASSES_IND
# 0.99 SCH_SSCLASSES_ALGG_M
# 0.99 SCH_SSCLASSES_ALGG_F
# 0.99 TOT_SSCLASSES_ALGG
# 0.99 SCH_SSCLASSES_OTHM_M
# 0.99 SCH_SSCLASSES_OTHM_F
# 0.99 TOT_SSCLASSES_OTHM
# 0.99 SCH_SSCLASSES_SCI_M
# 0.99 SCH_SSCLASSES_SCI_F
# 0.99 TOT_SSCLASSES_SCI
# 0.99 SCH_SSCLASSES_ENGL_M
# 0.99 SCH_SSCLASSES_ENGL_F
# 0.99 TOT_SSCLASSES_ENGL
# 0.99 SCH_SSCLASSES_OTHA_M
# 0.99 SCH_SSCLASSES_OTHA_F
# 0.99 TOT_SSCLASSES_OTHA
# 0.732 SCH_APENR_IND
# 0.86 SCH_APCOURSES
# 0.86 SCH_APSEL
# 0.86 SCH_APENR_HI_M
# 0.86 SCH_APENR_HI_F
# 0.86 SCH_APENR_AM_M
# 0.86 SCH_APENR_AM_F
# 0.86 SCH_APENR_AS_M
# 0.86 SCH_APENR_AS_F
# 0.86 SCH_APENR_HP_M
# 0.86 SCH_APENR_HP_F
# 0.86 SCH_APENR_BL_M
# 0.86 SCH_APENR_BL_F
# 0.86 SCH_APENR_WH_M
# 0.86 SCH_APENR_WH_F
# 0.86 SCH_APENR_TR_M
# 0.86 SCH_APENR_TR_F
# 0.86 TOT_APENR_M
# 0.86 TOT_APENR_F
# 0.86 SCH_APENR_LEP_M
# 0.86 SCH_APENR_LEP_F
# 0.86 SCH_APENR_IDEA_M
# 0.86 SCH_APENR_IDEA_F
# 0.86 SCH_APMATHENR_IND
# 0.889 SCH_APMATHENR_HI_M
# 0.889 SCH_APMATHENR_HI_F
# 0.889 SCH_APMATHENR_AM_M
# 0.889 SCH_APMATHENR_AM_F
# 0.889 SCH_APMATHENR_AS_M
# 0.889 SCH_APMATHENR_AS_F
# 0.889 SCH_APMATHENR_HP_M
# 0.889 SCH_APMATHENR_HP_F
# 0.889 SCH_APMATHENR_BL_M
# 0.889 SCH_APMATHENR_BL_F
# 0.889 SCH_APMATHENR_WH_M
# 0.889 SCH_APMATHENR_WH_F
# 0.889 SCH_APMATHENR_TR_M
# 0.889 SCH_APMATHENR_TR_F
# 0.889 TOT_APMATHENR_M
# 0.889 TOT_APMATHENR_F
# 0.889 SCH_APMATHENR_LEP_M
# 0.889 SCH_APMATHENR_LEP_F
# 0.889 SCH_APMATHENR_IDEA_M
# 0.889 SCH_APMATHENR_IDEA_F
# 0.86 SCH_APSCIENR_IND
# 0.896 SCH_APSCIENR_HI_M
# 0.896 SCH_APSCIENR_HI_F
# 0.896 SCH_APSCIENR_AM_M
# 0.896 SCH_APSCIENR_AM_F
# 0.896 SCH_APSCIENR_AS_M
# 0.896 SCH_APSCIENR_AS_F
# 0.896 SCH_APSCIENR_HP_M
# 0.896 SCH_APSCIENR_HP_F
# 0.896 SCH_APSCIENR_BL_M
# 0.896 SCH_APSCIENR_BL_F
# 0.896 SCH_APSCIENR_WH_M
# 0.896 SCH_APSCIENR_WH_F
# 0.896 SCH_APSCIENR_TR_M
# 0.896 SCH_APSCIENR_TR_F
# 0.896 TOT_APSCIENR_M
# 0.896 TOT_APSCIENR_F
# 0.896 SCH_APSCIENR_LEP_M
# 0.896 SCH_APSCIENR_LEP_F
# 0.896 SCH_APSCIENR_IDEA_M
# 0.896 SCH_APSCIENR_IDEA_F
# 0.86 SCH_APOTHENR_IND
# 0.869 SCH_APOTHENR_HI_M
# 0.869 SCH_APOTHENR_HI_F
# 0.869 SCH_APOTHENR_AM_M
# 0.869 SCH_APOTHENR_AM_F
# 0.869 SCH_APOTHENR_AS_M
# 0.869 SCH_APOTHENR_AS_F
# 0.869 SCH_APOTHENR_HP_M
# 0.869 SCH_APOTHENR_HP_F
# 0.869 SCH_APOTHENR_BL_M
# 0.869 SCH_APOTHENR_BL_F
# 0.869 SCH_APOTHENR_WH_M
# 0.869 SCH_APOTHENR_WH_F
# 0.869 SCH_APOTHENR_TR_M
# 0.869 SCH_APOTHENR_TR_F
# 0.869 TOT_APOTHENR_M
# 0.869 TOT_APOTHENR_F
# 0.869 SCH_APOTHENR_LEP_M
# 0.869 SCH_APOTHENR_LEP_F
# 0.869 SCH_APOTHENR_IDEA_M
# 0.869 SCH_APOTHENR_IDEA_F
# 0.86 SCH_APEXAM_ONEORMORE_HI_M
# 0.86 SCH_APEXAM_ONEORMORE_HI_F
# 0.86 SCH_APEXAM_ONEORMORE_AM_M
# 0.86 SCH_APEXAM_ONEORMORE_AM_F
# 0.86 SCH_APEXAM_ONEORMORE_AS_M
# 0.86 SCH_APEXAM_ONEORMORE_AS_F
# 0.86 SCH_APEXAM_ONEORMORE_HP_M
# 0.86 SCH_APEXAM_ONEORMORE_HP_F
# 0.86 SCH_APEXAM_ONEORMORE_BL_M
# 0.86 SCH_APEXAM_ONEORMORE_BL_F
# 0.86 SCH_APEXAM_ONEORMORE_WH_M
# 0.86 SCH_APEXAM_ONEORMORE_WH_F
# 0.86 SCH_APEXAM_ONEORMORE_TR_M
# 0.86 SCH_APEXAM_ONEORMORE_TR_F
# 0.86 TOT_APEXAM_ONEORMORE_M
# 0.86 TOT_APEXAM_ONEORMORE_F
# 0.86 SCH_APEXAM_ONEORMORE_LEP_M
# 0.86 SCH_APEXAM_ONEORMORE_LEP_F
# 0.86 SCH_APEXAM_ONEORMORE_IDEA_M
# 0.86 SCH_APEXAM_ONEORMORE_IDEA_F
# 0.86 SCH_APEXAM_NONE_HI_M
# 0.86 SCH_APEXAM_NONE_HI_F
# 0.86 SCH_APEXAM_NONE_AM_M
# 0.86 SCH_APEXAM_NONE_AM_F
# 0.86 SCH_APEXAM_NONE_AS_M
# 0.86 SCH_APEXAM_NONE_AS_F
# 0.86 SCH_APEXAM_NONE_HP_M
# 0.86 SCH_APEXAM_NONE_HP_F
# 0.86 SCH_APEXAM_NONE_BL_M
# 0.86 SCH_APEXAM_NONE_BL_F
# 0.86 SCH_APEXAM_NONE_WH_M
# 0.86 SCH_APEXAM_NONE_WH_F
# 0.86 SCH_APEXAM_NONE_TR_M
# 0.86 SCH_APEXAM_NONE_TR_F
# 0.86 TOT_APEXAM_NONE_M
# 0.86 TOT_APEXAM_NONE_F
# 0.86 SCH_APEXAM_NONE_LEP_M
# 0.86 SCH_APEXAM_NONE_LEP_F
# 0.86 SCH_APEXAM_NONE_IDEA_M
# 0.86 SCH_APEXAM_NONE_IDEA_F
# 0.953 SCH_APPASS_ONEORMORE_HI_M
# 0.949 SCH_APPASS_ONEORMORE_HI_F
# 0.999 SCH_APPASS_ONEORMORE_AM_M
# 0.999 SCH_APPASS_ONEORMORE_AM_F
# 0.964 SCH_APPASS_ONEORMORE_AS_M
# 0.961 SCH_APPASS_ONEORMORE_AS_F
# 0.999 SCH_APPASS_ONEORMORE_HP_M
# 0.999 SCH_APPASS_ONEORMORE_HP_F
# 0.978 SCH_APPASS_ONEORMORE_BL_M
# 0.969 SCH_APPASS_ONEORMORE_BL_F
# 0.914 SCH_APPASS_ONEORMORE_WH_M
# 0.911 SCH_APPASS_ONEORMORE_WH_F
# 0.982 SCH_APPASS_ONEORMORE_TR_M
# 0.978 SCH_APPASS_ONEORMORE_TR_F
# 0.903 TOT_APPASS_ONEORMORE_M
# 0.899 TOT_APPASS_ONEORMORE_F
# 0.994 SCH_APPASS_ONEORMORE_LEP_M
# 0.992 SCH_APPASS_ONEORMORE_LEP_F
# 0.992 SCH_APPASS_ONEORMORE_IDEA_M
# 0.997 SCH_APPASS_ONEORMORE_IDEA_F
# 0.955 SCH_APPASS_NONE_HI_M
# 0.948 SCH_APPASS_NONE_HI_F
# 0.999 SCH_APPASS_NONE_AM_M
# 0.998 SCH_APPASS_NONE_AM_F
# 0.973 SCH_APPASS_NONE_AS_M
# 0.968 SCH_APPASS_NONE_AS_F
# 0.999 SCH_APPASS_NONE_HP_M
# 0.999 SCH_APPASS_NONE_HP_F
# 0.965 SCH_APPASS_NONE_BL_M
# 0.956 SCH_APPASS_NONE_BL_F
# 0.915 SCH_APPASS_NONE_WH_M
# 0.909 SCH_APPASS_NONE_WH_F
# 0.988 SCH_APPASS_NONE_TR_M
# 0.982 SCH_APPASS_NONE_TR_F
# 0.898 TOT_APPASS_NONE_M
# 0.893 TOT_APPASS_NONE_F
# 0.994 SCH_APPASS_NONE_LEP_M
# 0.993 SCH_APPASS_NONE_LEP_F
# 0.992 SCH_APPASS_NONE_IDEA_M
# 0.995 SCH_APPASS_NONE_IDEA_F
# 0.732 SCH_IBENR_IND
# 0.991 SCH_IBENR_HI_M
# 0.991 SCH_IBENR_HI_F
# 0.991 SCH_IBENR_AM_M
# 0.991 SCH_IBENR_AM_F
# 0.991 SCH_IBENR_AS_M
# 0.991 SCH_IBENR_AS_F
# 0.991 SCH_IBENR_HP_M
# 0.991 SCH_IBENR_HP_F
# 0.991 SCH_IBENR_BL_M
# 0.991 SCH_IBENR_BL_F
# 0.991 SCH_IBENR_WH_M
# 0.991 SCH_IBENR_WH_F
# 0.991 SCH_IBENR_TR_M
# 0.991 SCH_IBENR_TR_F
# 0.991 TOT_IBENR_M
# 0.991 TOT_IBENR_F
# 0.991 SCH_IBENR_LEP_M
# 0.991 SCH_IBENR_LEP_F
# 0.991 SCH_IBENR_IDEA_M
# 0.991 SCH_IBENR_IDEA_F
# 0.726 SCH_SATACT_HI_M
# 0.726 SCH_SATACT_HI_F
# 0.726 SCH_SATACT_AM_M
# 0.726 SCH_SATACT_AM_F
# 0.726 SCH_SATACT_AS_M
# 0.726 SCH_SATACT_AS_F
# 0.726 SCH_SATACT_HP_M
# 0.726 SCH_SATACT_HP_F
# 0.726 SCH_SATACT_BL_M
# 0.726 SCH_SATACT_BL_F
# 0.726 SCH_SATACT_WH_M
# 0.726 SCH_SATACT_WH_F
# 0.726 SCH_SATACT_TR_M
# 0.726 SCH_SATACT_TR_F
# 0.726 TOT_SATACT_M
# 0.726 TOT_SATACT_F
# 0.726 SCH_SATACT_LEP_M
# 0.726 SCH_SATACT_LEP_F
# 0.726 SCH_SATACT_IDEA_M
# 0.726 SCH_SATACT_IDEA_F
# 0.0 SCH_CORPINSTANCES_IND
# 0.98 SCH_PSDISC_CORP_HI_M
# 0.98 SCH_PSDISC_CORP_HI_F
# 0.98 SCH_PSDISC_CORP_AM_M
# 0.98 SCH_PSDISC_CORP_AM_F
# 0.98 SCH_PSDISC_CORP_AS_M
# 0.98 SCH_PSDISC_CORP_AS_F
# 0.98 SCH_PSDISC_CORP_HP_M
# 0.98 SCH_PSDISC_CORP_HP_F
# 0.98 SCH_PSDISC_CORP_BL_M
# 0.98 SCH_PSDISC_CORP_BL_F
# 0.98 SCH_PSDISC_CORP_WH_M
# 0.98 SCH_PSDISC_CORP_WH_F
# 0.98 SCH_PSDISC_CORP_TR_M
# 0.98 SCH_PSDISC_CORP_TR_F
# 0.98 TOT_PSDISC_CORP_M
# 0.98 TOT_PSDISC_CORP_F
# 0.98 SCH_PSDISC_CORP_LEP_M
# 0.98 SCH_PSDISC_CORP_LEP_F
# 0.98 SCH_PSDISC_CORP_IDEA_M
# 0.98 SCH_PSDISC_CORP_IDEA_F
# 0.98 SCH_PSCORPINSTANCES_ALL
# 0.98 SCH_PSCORPINSTANCES_IDEA
# 0.95 SCH_DISCWODIS_CORP_HI_M
# 0.95 SCH_DISCWODIS_CORP_HI_F
# 0.95 SCH_DISCWODIS_CORP_AM_M
# 0.95 SCH_DISCWODIS_CORP_AM_F
# 0.95 SCH_DISCWODIS_CORP_AS_M
# 0.95 SCH_DISCWODIS_CORP_AS_F
# 0.95 SCH_DISCWODIS_CORP_HP_M
# 0.95 SCH_DISCWODIS_CORP_HP_F
# 0.95 SCH_DISCWODIS_CORP_BL_M
# 0.95 SCH_DISCWODIS_CORP_BL_F
# 0.95 SCH_DISCWODIS_CORP_WH_M
# 0.95 SCH_DISCWODIS_CORP_WH_F
# 0.95 SCH_DISCWODIS_CORP_TR_M
# 0.95 SCH_DISCWODIS_CORP_TR_F
# 0.95 TOT_DISCWODIS_CORP_M
# 0.95 TOT_DISCWODIS_CORP_F
# 0.95 SCH_DISCWODIS_CORP_LEP_M
# 0.95 SCH_DISCWODIS_CORP_LEP_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_HI_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_HI_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_AM_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_AM_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_AS_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_AS_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_HP_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_HP_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_BL_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_BL_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_WH_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_WH_F
# 0.95 SCH_DISCWDIS_CORP_IDEA_TR_M
# 0.95 SCH_DISCWDIS_CORP_IDEA_TR_F
# 0.95 TOT_DISCWDIS_CORP_IDEA_M
# 0.95 TOT_DISCWDIS_CORP_IDEA_F
# 0.95 SCH_DISCWDIS_CORP_LEP_M
# 0.95 SCH_DISCWDIS_CORP_LEP_F
# 0.95 SCH_DISCWDIS_CORP_504_M
# 0.95 SCH_DISCWDIS_CORP_504_F
# 0.95 SCH_CORPINSTANCES_WODIS
# 0.95 SCH_CORPINSTANCES_WDIS
# 0.689 SCH_PSDISC_SINGOOS_HI_M
# 0.689 SCH_PSDISC_SINGOOS_HI_F
# 0.689 SCH_PSDISC_SINGOOS_AM_M
# 0.689 SCH_PSDISC_SINGOOS_AM_F
# 0.689 SCH_PSDISC_SINGOOS_AS_M
# 0.689 SCH_PSDISC_SINGOOS_AS_F
# 0.689 SCH_PSDISC_SINGOOS_HP_M
# 0.689 SCH_PSDISC_SINGOOS_HP_F
# 0.689 SCH_PSDISC_SINGOOS_BL_M
# 0.689 SCH_PSDISC_SINGOOS_BL_F
# 0.689 SCH_PSDISC_SINGOOS_WH_M
# 0.689 SCH_PSDISC_SINGOOS_WH_F
# 0.689 SCH_PSDISC_SINGOOS_TR_M
# 0.689 SCH_PSDISC_SINGOOS_TR_F
# 0.689 TOT_PSDISC_SINGOOS_M
# 0.689 TOT_PSDISC_SINGOOS_F
# 0.689 SCH_PSDISC_SINGOOS_LEP_M
# 0.689 SCH_PSDISC_SINGOOS_LEP_F
# 0.689 SCH_PSDISC_SINGOOS_IDEA_M
# 0.689 SCH_PSDISC_SINGOOS_IDEA_F
# 0.689 SCH_PSDISC_MULTOOS_HI_M
# 0.689 SCH_PSDISC_MULTOOS_HI_F
# 0.689 SCH_PSDISC_MULTOOS_AM_M
# 0.689 SCH_PSDISC_MULTOOS_AM_F
# 0.689 SCH_PSDISC_MULTOOS_AS_M
# 0.689 SCH_PSDISC_MULTOOS_AS_F
# 0.689 SCH_PSDISC_MULTOOS_HP_M
# 0.689 SCH_PSDISC_MULTOOS_HP_F
# 0.689 SCH_PSDISC_MULTOOS_BL_M
# 0.689 SCH_PSDISC_MULTOOS_BL_F
# 0.689 SCH_PSDISC_MULTOOS_WH_M
# 0.689 SCH_PSDISC_MULTOOS_WH_F
# 0.689 SCH_PSDISC_MULTOOS_TR_M
# 0.689 SCH_PSDISC_MULTOOS_TR_F
# 0.689 TOT_PSDISC_MULTOOS_M
# 0.689 TOT_PSDISC_MULTOOS_F
# 0.689 SCH_PSDISC_MULTOOS_LEP_M
# 0.689 SCH_PSDISC_MULTOOS_LEP_F
# 0.689 SCH_PSDISC_MULTOOS_IDEA_M
# 0.689 SCH_PSDISC_MULTOOS_IDEA_F
# 0.689 SCH_PSOOSINSTANCES_ALL
# 0.689 SCH_PSOOSINSTANCES_IDEA
# 0.025 SCH_DISCWODIS_ISS_HI_M
# 0.025 SCH_DISCWODIS_ISS_HI_F
# 0.025 SCH_DISCWODIS_ISS_AM_M
# 0.025 SCH_DISCWODIS_ISS_AM_F
# 0.025 SCH_DISCWODIS_ISS_AS_M
# 0.025 SCH_DISCWODIS_ISS_AS_F
# 0.025 SCH_DISCWODIS_ISS_HP_M
# 0.025 SCH_DISCWODIS_ISS_HP_F
# 0.025 SCH_DISCWODIS_ISS_BL_M
# 0.025 SCH_DISCWODIS_ISS_BL_F
# 0.025 SCH_DISCWODIS_ISS_WH_M
# 0.025 SCH_DISCWODIS_ISS_WH_F
# 0.025 SCH_DISCWODIS_ISS_TR_M
# 0.025 SCH_DISCWODIS_ISS_TR_F
# 0.025 TOT_DISCWODIS_ISS_M
# 0.025 TOT_DISCWODIS_ISS_F
# 0.025 SCH_DISCWODIS_ISS_LEP_M
# 0.025 SCH_DISCWODIS_ISS_LEP_F
# 0.019 SCH_DISCWODIS_SINGOOS_HI_M
# 0.019 SCH_DISCWODIS_SINGOOS_HI_F
# 0.019 SCH_DISCWODIS_SINGOOS_AM_M
# 0.019 SCH_DISCWODIS_SINGOOS_AM_F
# 0.019 SCH_DISCWODIS_SINGOOS_AS_M
# 0.019 SCH_DISCWODIS_SINGOOS_AS_F
# 0.019 SCH_DISCWODIS_SINGOOS_HP_M
# 0.019 SCH_DISCWODIS_SINGOOS_HP_F
# 0.019 SCH_DISCWODIS_SINGOOS_BL_M
# 0.019 SCH_DISCWODIS_SINGOOS_BL_F
# 0.019 SCH_DISCWODIS_SINGOOS_WH_M
# 0.019 SCH_DISCWODIS_SINGOOS_WH_F
# 0.019 SCH_DISCWODIS_SINGOOS_TR_M
# 0.019 SCH_DISCWODIS_SINGOOS_TR_F
# 0.019 TOT_DISCWODIS_SINGOOS_M
# 0.019 TOT_DISCWODIS_SINGOOS_F
# 0.019 SCH_DISCWODIS_SINGOOS_LEP_M
# 0.019 SCH_DISCWODIS_SINGOOS_LEP_F
# 0.019 SCH_DISCWODIS_MULTOOS_HI_M
# 0.019 SCH_DISCWODIS_MULTOOS_HI_F
# 0.019 SCH_DISCWODIS_MULTOOS_AM_M
# 0.019 SCH_DISCWODIS_MULTOOS_AM_F
# 0.019 SCH_DISCWODIS_MULTOOS_AS_M
# 0.019 SCH_DISCWODIS_MULTOOS_AS_F
# 0.019 SCH_DISCWODIS_MULTOOS_HP_M
# 0.019 SCH_DISCWODIS_MULTOOS_HP_F
# 0.019 SCH_DISCWODIS_MULTOOS_BL_M
# 0.019 SCH_DISCWODIS_MULTOOS_BL_F
# 0.019 SCH_DISCWODIS_MULTOOS_WH_M
# 0.019 SCH_DISCWODIS_MULTOOS_WH_F
# 0.019 SCH_DISCWODIS_MULTOOS_TR_M
# 0.019 SCH_DISCWODIS_MULTOOS_TR_F
# 0.019 TOT_DISCWODIS_MULTOOS_M
# 0.019 TOT_DISCWODIS_MULTOOS_F
# 0.019 SCH_DISCWODIS_MULTOOS_LEP_M
# 0.019 SCH_DISCWODIS_MULTOOS_LEP_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_HI_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_HI_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_AM_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_AM_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_AS_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_AS_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_HP_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_HP_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_BL_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_BL_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_WH_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_WH_F
# 0.025 SCH_DISCWDIS_ISS_IDEA_TR_M
# 0.025 SCH_DISCWDIS_ISS_IDEA_TR_F
# 0.025 TOT_DISCWDIS_ISS_IDEA_M
# 0.025 TOT_DISCWDIS_ISS_IDEA_F
# 0.025 SCH_DISCWDIS_ISS_LEP_M
# 0.025 SCH_DISCWDIS_ISS_LEP_F
# 0.025 SCH_DISCWDIS_ISS_504_M
# 0.025 SCH_DISCWDIS_ISS_504_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_HI_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_HI_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_AM_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_AM_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_AS_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_AS_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_HP_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_HP_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_BL_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_BL_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_WH_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_WH_F
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_TR_M
# 0.019 SCH_DISCWDIS_SINGOOS_IDEA_TR_F
# 0.019 TOT_DISCWDIS_SINGOOS_IDEA_M
# 0.019 TOT_DISCWDIS_SINGOOS_IDEA_F
# 0.019 SCH_DISCWDIS_SINGOOS_LEP_M
# 0.019 SCH_DISCWDIS_SINGOOS_LEP_F
# 0.019 SCH_DISCWDIS_SINGOOS_504_M
# 0.019 SCH_DISCWDIS_SINGOOS_504_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_HI_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_HI_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_AM_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_AM_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_AS_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_AS_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_HP_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_HP_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_BL_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_BL_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_WH_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_WH_F
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_TR_M
# 0.019 SCH_DISCWDIS_MULTOOS_IDEA_TR_F
# 0.019 TOT_DISCWDIS_MULTOOS_IDEA_M
# 0.019 TOT_DISCWDIS_MULTOOS_IDEA_F
# 0.019 SCH_DISCWDIS_MULTOOS_LEP_M
# 0.019 SCH_DISCWDIS_MULTOOS_LEP_F
# 0.019 SCH_DISCWDIS_MULTOOS_504_M
# 0.019 SCH_DISCWDIS_MULTOOS_504_F
# 0.019 SCH_OOSINSTANCES_WODIS
# 0.019 SCH_OOSINSTANCES_IDEA
# 0.019 SCH_OOSINSTANCES_504
# 0.019 SCH_DAYSMISSED_HI_M
# 0.019 SCH_DAYSMISSED_HI_F
# 0.019 SCH_DAYSMISSED_AM_M
# 0.019 SCH_DAYSMISSED_AM_F
# 0.019 SCH_DAYSMISSED_AS_M
# 0.019 SCH_DAYSMISSED_AS_F
# 0.019 SCH_DAYSMISSED_HP_M
# 0.019 SCH_DAYSMISSED_HP_F
# 0.019 SCH_DAYSMISSED_BL_M
# 0.019 SCH_DAYSMISSED_BL_F
# 0.019 SCH_DAYSMISSED_WH_M
# 0.019 SCH_DAYSMISSED_WH_F
# 0.019 SCH_DAYSMISSED_TR_M
# 0.019 SCH_DAYSMISSED_TR_F
# 0.019 TOT_DAYSMISSED_M
# 0.019 TOT_DAYSMISSED_F
# 0.019 SCH_DAYSMISSED_LEP_M
# 0.019 SCH_DAYSMISSED_LEP_F
# 0.019 SCH_DAYSMISSED_504_M
# 0.019 SCH_DAYSMISSED_504_F
# 0.019 SCH_DAYSMISSED_IDEA_M
# 0.019 SCH_DAYSMISSED_IDEA_F
# 0.689 SCH_PSDISC_EXP_HI_M
# 0.689 SCH_PSDISC_EXP_HI_F
# 0.689 SCH_PSDISC_EXP_AM_M
# 0.689 SCH_PSDISC_EXP_AM_F
# 0.689 SCH_PSDISC_EXP_AS_M
# 0.689 SCH_PSDISC_EXP_AS_F
# 0.689 SCH_PSDISC_EXP_HP_M
# 0.689 SCH_PSDISC_EXP_HP_F
# 0.689 SCH_PSDISC_EXP_BL_M
# 0.689 SCH_PSDISC_EXP_BL_F
# 0.689 SCH_PSDISC_EXP_WH_M
# 0.689 SCH_PSDISC_EXP_WH_F
# 0.689 SCH_PSDISC_EXP_TR_M
# 0.689 SCH_PSDISC_EXP_TR_F
# 0.689 TOT_PSDISC_EXP_M
# 0.689 TOT_PSDISC_EXP_F
# 0.689 SCH_PSDISC_EXP_LEP_M
# 0.689 SCH_PSDISC_EXP_LEP_F
# 0.689 SCH_PSDISC_EXP_IDEA_M
# 0.689 SCH_PSDISC_EXP_IDEA_F
# 0.025 SCH_DISCWODIS_EXPWE_HI_M
# 0.025 SCH_DISCWODIS_EXPWE_HI_F
# 0.025 SCH_DISCWODIS_EXPWE_AM_M
# 0.025 SCH_DISCWODIS_EXPWE_AM_F
# 0.025 SCH_DISCWODIS_EXPWE_AS_M
# 0.025 SCH_DISCWODIS_EXPWE_AS_F
# 0.025 SCH_DISCWODIS_EXPWE_HP_M
# 0.025 SCH_DISCWODIS_EXPWE_HP_F
# 0.025 SCH_DISCWODIS_EXPWE_BL_M
# 0.025 SCH_DISCWODIS_EXPWE_BL_F
# 0.025 SCH_DISCWODIS_EXPWE_WH_M
# 0.025 SCH_DISCWODIS_EXPWE_WH_F
# 0.025 SCH_DISCWODIS_EXPWE_TR_M
# 0.025 SCH_DISCWODIS_EXPWE_TR_F
# 0.025 TOT_DISCWODIS_EXPWE_M
# 0.025 TOT_DISCWODIS_EXPWE_F
# 0.025 SCH_DISCWODIS_EXPWE_LEP_M
# 0.025 SCH_DISCWODIS_EXPWE_LEP_F
# 0.019 SCH_DISCWODIS_EXPWOE_HI_M
# 0.019 SCH_DISCWODIS_EXPWOE_HI_F
# 0.019 SCH_DISCWODIS_EXPWOE_AM_M
# 0.019 SCH_DISCWODIS_EXPWOE_AM_F
# 0.019 SCH_DISCWODIS_EXPWOE_AS_M
# 0.019 SCH_DISCWODIS_EXPWOE_AS_F
# 0.019 SCH_DISCWODIS_EXPWOE_HP_M
# 0.019 SCH_DISCWODIS_EXPWOE_HP_F
# 0.019 SCH_DISCWODIS_EXPWOE_BL_M
# 0.019 SCH_DISCWODIS_EXPWOE_BL_F
# 0.019 SCH_DISCWODIS_EXPWOE_WH_M
# 0.019 SCH_DISCWODIS_EXPWOE_WH_F
# 0.019 SCH_DISCWODIS_EXPWOE_TR_M
# 0.019 SCH_DISCWODIS_EXPWOE_TR_F
# 0.019 TOT_DISCWODIS_EXPWOE_M
# 0.019 TOT_DISCWODIS_EXPWOE_F
# 0.019 SCH_DISCWODIS_EXPWOE_LEP_M
# 0.019 SCH_DISCWODIS_EXPWOE_LEP_F
# 0.019 SCH_DISCWODIS_EXPZT_HI_M
# 0.019 SCH_DISCWODIS_EXPZT_HI_F
# 0.019 SCH_DISCWODIS_EXPZT_AM_M
# 0.019 SCH_DISCWODIS_EXPZT_AM_F
# 0.019 SCH_DISCWODIS_EXPZT_AS_M
# 0.019 SCH_DISCWODIS_EXPZT_AS_F
# 0.019 SCH_DISCWODIS_EXPZT_HP_M
# 0.019 SCH_DISCWODIS_EXPZT_HP_F
# 0.019 SCH_DISCWODIS_EXPZT_BL_M
# 0.019 SCH_DISCWODIS_EXPZT_BL_F
# 0.019 SCH_DISCWODIS_EXPZT_WH_M
# 0.019 SCH_DISCWODIS_EXPZT_WH_F
# 0.019 SCH_DISCWODIS_EXPZT_TR_M
# 0.019 SCH_DISCWODIS_EXPZT_TR_F
# 0.019 TOT_DISCWODIS_EXPZT_M
# 0.019 TOT_DISCWODIS_EXPZT_F
# 0.019 SCH_DISCWODIS_EXPZT_LEP_M
# 0.019 SCH_DISCWODIS_EXPZT_LEP_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_HI_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_HI_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_AM_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_AM_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_AS_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_AS_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_HP_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_HP_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_BL_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_BL_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_WH_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_WH_F
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_TR_M
# 0.025 SCH_DISCWDIS_EXPWE_IDEA_TR_F
# 0.025 TOT_DISCWDIS_EXPWE_IDEA_M
# 0.025 TOT_DISCWDIS_EXPWE_IDEA_F
# 0.025 SCH_DISCWDIS_EXPWE_LEP_M
# 0.025 SCH_DISCWDIS_EXPWE_LEP_F
# 0.025 SCH_DISCWDIS_EXPWE_504_M
# 0.025 SCH_DISCWDIS_EXPWE_504_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_HI_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_HI_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_AM_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_AM_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_AS_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_AS_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_HP_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_HP_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_BL_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_BL_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_WH_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_WH_F
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_TR_M
# 0.025 SCH_DISCWDIS_EXPWOE_IDEA_TR_F
# 0.025 TOT_DISCWDIS_EXPWOE_IDEA_M
# 0.025 TOT_DISCWDIS_EXPWOE_IDEA_F
# 0.019 SCH_DISCWDIS_EXPWOE_LEP_M
# 0.019 SCH_DISCWDIS_EXPWOE_LEP_F
# 0.019 SCH_DISCWDIS_EXPWOE_504_M
# 0.019 SCH_DISCWDIS_EXPWOE_504_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_HI_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_HI_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_AM_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_AM_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_AS_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_AS_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_HP_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_HP_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_BL_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_BL_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_WH_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_WH_F
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_TR_M
# 0.025 SCH_DISCWDIS_EXPZT_IDEA_TR_F
# 0.025 TOT_DISCWDIS_EXPZT_IDEA_M
# 0.025 TOT_DISCWDIS_EXPZT_IDEA_F
# 0.019 SCH_DISCWDIS_EXPZT_LEP_M
# 0.019 SCH_DISCWDIS_EXPZT_LEP_F
# 0.019 SCH_DISCWDIS_EXPZT_504_M
# 0.019 SCH_DISCWDIS_EXPZT_504_F
# 0.025 SCH_DISCWODIS_TFRALT_HI_M
# 0.025 SCH_DISCWODIS_TFRALT_HI_F
# 0.025 SCH_DISCWODIS_TFRALT_AM_M
# 0.025 SCH_DISCWODIS_TFRALT_AM_F
# 0.025 SCH_DISCWODIS_TFRALT_AS_M
# 0.025 SCH_DISCWODIS_TFRALT_AS_F
# 0.025 SCH_DISCWODIS_TFRALT_HP_M
# 0.025 SCH_DISCWODIS_TFRALT_HP_F
# 0.025 SCH_DISCWODIS_TFRALT_BL_M
# 0.025 SCH_DISCWODIS_TFRALT_BL_F
# 0.025 SCH_DISCWODIS_TFRALT_WH_M
# 0.025 SCH_DISCWODIS_TFRALT_WH_F
# 0.025 SCH_DISCWODIS_TFRALT_TR_M
# 0.025 SCH_DISCWODIS_TFRALT_TR_F
# 0.025 TOT_DISCWODIS_TFRALT_M
# 0.025 TOT_DISCWODIS_TFRALT_F
# 0.025 SCH_DISCWODIS_TFRALT_LEP_M
# 0.025 SCH_DISCWODIS_TFRALT_LEP_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_HI_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_HI_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_AM_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_AM_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_AS_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_AS_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_HP_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_HP_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_BL_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_BL_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_WH_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_WH_F
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_TR_M
# 0.025 SCH_DISCWDIS_TFRALT_IDEA_TR_F
# 0.025 TOT_DISCWDIS_TFRALT_IDEA_M
# 0.025 TOT_DISCWDIS_TFRALT_IDEA_F
# 0.025 SCH_DISCWDIS_TFRALT_LEP_M
# 0.025 SCH_DISCWDIS_TFRALT_LEP_F
# 0.025 SCH_DISCWDIS_TFRALT_504_M
# 0.025 SCH_DISCWDIS_TFRALT_504_F
# 0.025 SCH_DISCWODIS_REF_HI_M
# 0.025 SCH_DISCWODIS_REF_HI_F
# 0.025 SCH_DISCWODIS_REF_AM_M
# 0.025 SCH_DISCWODIS_REF_AM_F
# 0.025 SCH_DISCWODIS_REF_AS_M
# 0.025 SCH_DISCWODIS_REF_AS_F
# 0.025 SCH_DISCWODIS_REF_HP_M
# 0.025 SCH_DISCWODIS_REF_HP_F
# 0.025 SCH_DISCWODIS_REF_BL_M
# 0.025 SCH_DISCWODIS_REF_BL_F
# 0.025 SCH_DISCWODIS_REF_WH_M
# 0.025 SCH_DISCWODIS_REF_WH_F
# 0.025 SCH_DISCWODIS_REF_TR_M
# 0.025 SCH_DISCWODIS_REF_TR_F
# 0.025 TOT_DISCWODIS_REF_M
# 0.025 TOT_DISCWODIS_REF_F
# 0.025 SCH_DISCWODIS_REF_LEP_M
# 0.025 SCH_DISCWODIS_REF_LEP_F
# 0.025 SCH_DISCWDIS_REF_IDEA_HI_M
# 0.025 SCH_DISCWDIS_REF_IDEA_HI_F
# 0.025 SCH_DISCWDIS_REF_IDEA_AM_M
# 0.025 SCH_DISCWDIS_REF_IDEA_AM_F
# 0.025 SCH_DISCWDIS_REF_IDEA_AS_M
# 0.025 SCH_DISCWDIS_REF_IDEA_AS_F
# 0.025 SCH_DISCWDIS_REF_IDEA_HP_M
# 0.025 SCH_DISCWDIS_REF_IDEA_HP_F
# 0.025 SCH_DISCWDIS_REF_IDEA_BL_M
# 0.025 SCH_DISCWDIS_REF_IDEA_BL_F
# 0.025 SCH_DISCWDIS_REF_IDEA_WH_M
# 0.025 SCH_DISCWDIS_REF_IDEA_WH_F
# 0.025 SCH_DISCWDIS_REF_IDEA_TR_M
# 0.025 SCH_DISCWDIS_REF_IDEA_TR_F
# 0.025 TOT_DISCWDIS_REF_IDEA_M
# 0.025 TOT_DISCWDIS_REF_IDEA_F
# 0.025 SCH_DISCWDIS_REF_LEP_M
# 0.025 SCH_DISCWDIS_REF_LEP_F
# 0.025 SCH_DISCWDIS_REF_504_M
# 0.025 SCH_DISCWDIS_REF_504_F
# 0.044 SCH_DISCWODIS_ARR_HI_M
# 0.044 SCH_DISCWODIS_ARR_HI_F
# 0.044 SCH_DISCWODIS_ARR_AM_M
# 0.044 SCH_DISCWODIS_ARR_AM_F
# 0.044 SCH_DISCWODIS_ARR_AS_M
# 0.044 SCH_DISCWODIS_ARR_AS_F
# 0.044 SCH_DISCWODIS_ARR_HP_M
# 0.044 SCH_DISCWODIS_ARR_HP_F
# 0.044 SCH_DISCWODIS_ARR_BL_M
# 0.044 SCH_DISCWODIS_ARR_BL_F
# 0.044 SCH_DISCWODIS_ARR_WH_M
# 0.044 SCH_DISCWODIS_ARR_WH_F
# 0.044 SCH_DISCWODIS_ARR_TR_M
# 0.044 SCH_DISCWODIS_ARR_TR_F
# 0.044 TOT_DISCWODIS_ARR_M
# 0.044 TOT_DISCWODIS_ARR_F
# 0.044 SCH_DISCWODIS_ARR_LEP_M
# 0.044 SCH_DISCWODIS_ARR_LEP_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_HI_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_HI_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_AM_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_AM_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_AS_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_AS_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_HP_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_HP_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_BL_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_BL_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_WH_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_WH_F
# 0.044 SCH_DISCWDIS_ARR_IDEA_TR_M
# 0.044 SCH_DISCWDIS_ARR_IDEA_TR_F
# 0.044 TOT_DISCWDIS_ARR_IDEA_M
# 0.044 TOT_DISCWDIS_ARR_IDEA_F
# 0.044 SCH_DISCWDIS_ARR_LEP_M
# 0.044 SCH_DISCWDIS_ARR_LEP_F
# 0.044 SCH_DISCWDIS_ARR_504_M
# 0.044 SCH_DISCWDIS_ARR_504_F
# 0.0 SCH_FIREARM_IND
# 0.002 SCH_HOMICIDE_IND
# 0.017 SCH_OFFENSE_RAPE
# 0.017 SCH_OFFENSE_BATT
# 0.019 SCH_OFFENSE_ROBWW
# 0.019 SCH_OFFENSE_ROBWX
# 0.019 SCH_OFFENSE_ROBWOW
# 0.019 SCH_OFFENSE_ATTWW
# 0.019 SCH_OFFENSE_ATTWX
# 0.02 SCH_OFFENSE_ATTWOW
# 0.019 SCH_OFFENSE_THRWW
# 0.019 SCH_OFFENSE_THRWX
# 0.02 SCH_OFFENSE_THRWOW
# 0.017 SCH_OFFENSE_POSSWX
# 0.042 SCH_RS_NONIDEA_MECH_HI_M
# 0.042 SCH_RS_NONIDEA_MECH_HI_F
# 0.042 SCH_RS_NONIDEA_MECH_AM_M
# 0.042 SCH_RS_NONIDEA_MECH_AM_F
# 0.042 SCH_RS_NONIDEA_MECH_AS_M
# 0.042 SCH_RS_NONIDEA_MECH_AS_F
# 0.042 SCH_RS_NONIDEA_MECH_HP_M
# 0.042 SCH_RS_NONIDEA_MECH_HP_F
# 0.042 SCH_RS_NONIDEA_MECH_BL_M
# 0.042 SCH_RS_NONIDEA_MECH_BL_F
# 0.042 SCH_RS_NONIDEA_MECH_WH_M
# 0.042 SCH_RS_NONIDEA_MECH_WH_F
# 0.043 SCH_RS_NONIDEA_MECH_TR_M
# 0.043 SCH_RS_NONIDEA_MECH_TR_F
# 0.042 TOT_RS_NONIDEA_MECH_M
# 0.042 TOT_RS_NONIDEA_MECH_F
# 0.042 SCH_RS_NONIDEA_MECH_LEP_M
# 0.042 SCH_RS_NONIDEA_MECH_LEP_F
# 0.041 SCH_RS_NONIDEA_MECH_504_M
# 0.041 SCH_RS_NONIDEA_MECH_504_F
# 0.025 SCH_RS_NONIDEA_PHYS_HI_M
# 0.025 SCH_RS_NONIDEA_PHYS_HI_F
# 0.025 SCH_RS_NONIDEA_PHYS_AM_M
# 0.025 SCH_RS_NONIDEA_PHYS_AM_F
# 0.025 SCH_RS_NONIDEA_PHYS_AS_M
# 0.025 SCH_RS_NONIDEA_PHYS_AS_F
# 0.025 SCH_RS_NONIDEA_PHYS_HP_M
# 0.025 SCH_RS_NONIDEA_PHYS_HP_F
# 0.025 SCH_RS_NONIDEA_PHYS_BL_M
# 0.025 SCH_RS_NONIDEA_PHYS_BL_F
# 0.025 SCH_RS_NONIDEA_PHYS_WH_M
# 0.025 SCH_RS_NONIDEA_PHYS_WH_F
# 0.025 SCH_RS_NONIDEA_PHYS_TR_M
# 0.025 SCH_RS_NONIDEA_PHYS_TR_F
# 0.025 TOT_RS_NONIDEA_PHYS_M
# 0.025 TOT_RS_NONIDEA_PHYS_F
# 0.025 SCH_RS_NONIDEA_PHYS_LEP_M
# 0.025 SCH_RS_NONIDEA_PHYS_LEP_F
# 0.024 SCH_RS_NONIDEA_PHYS_504_M
# 0.024 SCH_RS_NONIDEA_PHYS_504_F
# 0.025 SCH_RS_NONIDEA_SECL_HI_M
# 0.025 SCH_RS_NONIDEA_SECL_HI_F
# 0.025 SCH_RS_NONIDEA_SECL_AM_M
# 0.025 SCH_RS_NONIDEA_SECL_AM_F
# 0.025 SCH_RS_NONIDEA_SECL_AS_M
# 0.025 SCH_RS_NONIDEA_SECL_AS_F
# 0.025 SCH_RS_NONIDEA_SECL_HP_M
# 0.025 SCH_RS_NONIDEA_SECL_HP_F
# 0.025 SCH_RS_NONIDEA_SECL_BL_M
# 0.025 SCH_RS_NONIDEA_SECL_BL_F
# 0.025 SCH_RS_NONIDEA_SECL_WH_M
# 0.025 SCH_RS_NONIDEA_SECL_WH_F
# 0.025 SCH_RS_NONIDEA_SECL_TR_M
# 0.025 SCH_RS_NONIDEA_SECL_TR_F
# 0.025 TOT_RS_NONIDEA_SECL_M
# 0.025 TOT_RS_NONIDEA_SECL_F
# 0.024 SCH_RS_NONIDEA_SECL_504_M
# 0.023 SCH_RS_NONIDEA_SECL_504_F
# 0.025 SCH_RS_NONIDEA_SECL_LEP_M
# 0.025 SCH_RS_NONIDEA_SECL_LEP_F
# 0.041 SCH_RS_IDEA_MECH_HI_M
# 0.041 SCH_RS_IDEA_MECH_HI_F
# 0.041 SCH_RS_IDEA_MECH_AM_M
# 0.041 SCH_RS_IDEA_MECH_AM_F
# 0.041 SCH_RS_IDEA_MECH_AS_M
# 0.041 SCH_RS_IDEA_MECH_AS_F
# 0.041 SCH_RS_IDEA_MECH_HP_M
# 0.041 SCH_RS_IDEA_MECH_HP_F
# 0.041 SCH_RS_IDEA_MECH_BL_M
# 0.041 SCH_RS_IDEA_MECH_BL_F
# 0.041 SCH_RS_IDEA_MECH_WH_M
# 0.041 SCH_RS_IDEA_MECH_WH_F
# 0.041 SCH_RS_IDEA_MECH_TR_M
# 0.041 SCH_RS_IDEA_MECH_TR_F
# 0.041 TOT_RS_IDEA_MECH_M
# 0.041 TOT_RS_IDEA_MECH_F
# 0.041 SCH_RS_IDEA_MECH_LEP_M
# 0.041 SCH_RS_IDEA_MECH_LEP_F
# 0.024 SCH_RS_IDEA_PHYS_HI_M
# 0.024 SCH_RS_IDEA_PHYS_HI_F
# 0.024 SCH_RS_IDEA_PHYS_AM_M
# 0.024 SCH_RS_IDEA_PHYS_AM_F
# 0.024 SCH_RS_IDEA_PHYS_AS_M
# 0.024 SCH_RS_IDEA_PHYS_AS_F
# 0.024 SCH_RS_IDEA_PHYS_HP_M
# 0.024 SCH_RS_IDEA_PHYS_HP_F
# 0.024 SCH_RS_IDEA_PHYS_BL_M
# 0.024 SCH_RS_IDEA_PHYS_BL_F
# 0.024 SCH_RS_IDEA_PHYS_WH_M
# 0.024 SCH_RS_IDEA_PHYS_WH_F
# 0.024 SCH_RS_IDEA_PHYS_TR_M
# 0.024 SCH_RS_IDEA_PHYS_TR_F
# 0.024 TOT_RS_IDEA_PHYS_M
# 0.024 TOT_RS_IDEA_PHYS_F
# 0.024 SCH_RS_IDEA_PHYS_LEP_M
# 0.024 SCH_RS_IDEA_PHYS_LEP_F
# 0.023 SCH_RS_IDEA_SECL_HI_M
# 0.023 SCH_RS_IDEA_SECL_HI_F
# 0.023 SCH_RS_IDEA_SECL_AM_M
# 0.023 SCH_RS_IDEA_SECL_AM_F
# 0.023 SCH_RS_IDEA_SECL_AS_M
# 0.023 SCH_RS_IDEA_SECL_AS_F
# 0.023 SCH_RS_IDEA_SECL_HP_M
# 0.023 SCH_RS_IDEA_SECL_HP_F
# 0.023 SCH_RS_IDEA_SECL_BL_M
# 0.023 SCH_RS_IDEA_SECL_BL_F
# 0.023 SCH_RS_IDEA_SECL_WH_M
# 0.023 SCH_RS_IDEA_SECL_WH_F
# 0.023 SCH_RS_IDEA_SECL_TR_M
# 0.023 SCH_RS_IDEA_SECL_TR_F
# 0.023 TOT_RS_IDEA_SECL_M
# 0.023 TOT_RS_IDEA_SECL_F
# 0.023 SCH_RS_IDEA_SECL_LEP_M
# 0.023 SCH_RS_IDEA_SECL_LEP_F
# 0.043 SCH_RSINSTANCES_MECH_WODIS
# 0.041 SCH_RSINSTANCES_MECH_IDEA
# 0.043 SCH_RSINSTANCES_MECH_504
# 0.025 SCH_RSINSTANCES_PHYS_WODIS
# 0.023 SCH_RSINSTANCES_PHYS_IDEA
# 0.025 SCH_RSINSTANCES_PHYS_504
# 0.025 SCH_RSINSTANCES_SECL_WODIS
# 0.023 SCH_RSINSTANCES_SECL_IDEA
# 0.025 SCH_RSINSTANCES_SECL_504
# 0.023 SCH_HBALLEGATIONS_SEX
# 0.023 SCH_HBALLEGATIONS_RAC
# 0.023 SCH_HBALLEGATIONS_DIS
# 0.024 SCH_HBALLEGATIONS_ORI
# 0.024 SCH_HBALLEGATIONS_REL
# 0.024 SCH_HBREPORTED_SEX_HI_M
# 0.024 SCH_HBREPORTED_SEX_HI_F
# 0.024 SCH_HBREPORTED_SEX_AM_M
# 0.024 SCH_HBREPORTED_SEX_AM_F
# 0.024 SCH_HBREPORTED_SEX_AS_M
# 0.024 SCH_HBREPORTED_SEX_AS_F
# 0.024 SCH_HBREPORTED_SEX_HP_M
# 0.024 SCH_HBREPORTED_SEX_HP_F
# 0.024 SCH_HBREPORTED_SEX_BL_M
# 0.024 SCH_HBREPORTED_SEX_BL_F
# 0.024 SCH_HBREPORTED_SEX_WH_M
# 0.024 SCH_HBREPORTED_SEX_WH_F
# 0.024 SCH_HBREPORTED_SEX_TR_M
# 0.024 SCH_HBREPORTED_SEX_TR_F
# 0.024 TOT_HBREPORTED_SEX_M
# 0.024 TOT_HBREPORTED_SEX_F
# 0.024 SCH_HBREPORTED_SEX_LEP_M
# 0.024 SCH_HBREPORTED_SEX_LEP_F
# 0.024 SCH_HBREPORTED_SEX_IDEA_M
# 0.024 SCH_HBREPORTED_SEX_IDEA_F
# 0.024 SCH_HBREPORTED_SEX_504_M
# 0.024 SCH_HBREPORTED_SEX_504_F
# 0.023 SCH_HBREPORTED_RAC_HI_M
# 0.023 SCH_HBREPORTED_RAC_HI_F
# 0.023 SCH_HBREPORTED_RAC_AM_M
# 0.023 SCH_HBREPORTED_RAC_AM_F
# 0.023 SCH_HBREPORTED_RAC_AS_M
# 0.023 SCH_HBREPORTED_RAC_AS_F
# 0.023 SCH_HBREPORTED_RAC_HP_M
# 0.023 SCH_HBREPORTED_RAC_HP_F
# 0.023 SCH_HBREPORTED_RAC_BL_M
# 0.023 SCH_HBREPORTED_RAC_BL_F
# 0.023 SCH_HBREPORTED_RAC_WH_M
# 0.023 SCH_HBREPORTED_RAC_WH_F
# 0.023 SCH_HBREPORTED_RAC_TR_M
# 0.023 SCH_HBREPORTED_RAC_TR_F
# 0.023 TOT_HBREPORTED_RAC_M
# 0.023 TOT_HBREPORTED_RAC_F
# 0.023 SCH_HBREPORTED_RAC_LEP_M
# 0.023 SCH_HBREPORTED_RAC_LEP_F
# 0.023 SCH_HBREPORTED_RAC_IDEA_M
# 0.023 SCH_HBREPORTED_RAC_IDEA_F
# 0.023 SCH_HBREPORTED_RAC_504_M
# 0.023 SCH_HBREPORTED_RAC_504_F
# 0.023 SCH_HBREPORTED_DIS_HI_M
# 0.023 SCH_HBREPORTED_DIS_HI_F
# 0.023 SCH_HBREPORTED_DIS_AM_M
# 0.023 SCH_HBREPORTED_DIS_AM_F
# 0.023 SCH_HBREPORTED_DIS_AS_M
# 0.023 SCH_HBREPORTED_DIS_AS_F
# 0.023 SCH_HBREPORTED_DIS_HP_M
# 0.023 SCH_HBREPORTED_DIS_HP_F
# 0.023 SCH_HBREPORTED_DIS_BL_M
# 0.023 SCH_HBREPORTED_DIS_BL_F
# 0.023 SCH_HBREPORTED_DIS_WH_M
# 0.023 SCH_HBREPORTED_DIS_WH_F
# 0.023 SCH_HBREPORTED_DIS_TR_M
# 0.023 SCH_HBREPORTED_DIS_TR_F
# 0.023 TOT_HBREPORTED_DIS_M
# 0.023 TOT_HBREPORTED_DIS_F
# 0.023 SCH_HBREPORTED_DIS_LEP_M
# 0.023 SCH_HBREPORTED_DIS_LEP_F
# 0.023 SCH_HBREPORTED_DIS_IDEA_M
# 0.023 SCH_HBREPORTED_DIS_IDEA_F
# 0.023 SCH_HBREPORTED_DIS_504_M
# 0.023 SCH_HBREPORTED_DIS_504_F
# 0.021 SCH_HBDISCIPLINED_SEX_HI_M
# 0.021 SCH_HBDISCIPLINED_SEX_HI_F
# 0.021 SCH_HBDISCIPLINED_SEX_AM_M
# 0.021 SCH_HBDISCIPLINED_SEX_AM_F
# 0.021 SCH_HBDISCIPLINED_SEX_AS_M
# 0.021 SCH_HBDISCIPLINED_SEX_AS_F
# 0.021 SCH_HBDISCIPLINED_SEX_HP_M
# 0.021 SCH_HBDISCIPLINED_SEX_HP_F
# 0.021 SCH_HBDISCIPLINED_SEX_BL_M
# 0.021 SCH_HBDISCIPLINED_SEX_BL_F
# 0.021 SCH_HBDISCIPLINED_SEX_WH_M
# 0.021 SCH_HBDISCIPLINED_SEX_WH_F
# 0.021 SCH_HBDISCIPLINED_SEX_TR_M
# 0.021 SCH_HBDISCIPLINED_SEX_TR_F
# 0.021 TOT_HBDISCIPLINED_SEX_M
# 0.021 TOT_HBDISCIPLINED_SEX_F
# 0.021 SCH_HBDISCIPLINED_SEX_LEP_M
# 0.021 SCH_HBDISCIPLINED_SEX_LEP_F
# 0.021 SCH_HBDISCIPLINED_SEX_IDEA_M
# 0.021 SCH_HBDISCIPLINED_SEX_IDEA_F
# 0.021 SCH_HBDISCIPLINED_SEX_504_M
# 0.021 SCH_HBDISCIPLINED_SEX_504_F
# 0.021 SCH_HBDISCIPLINED_RAC_HI_M
# 0.021 SCH_HBDISCIPLINED_RAC_HI_F
# 0.021 SCH_HBDISCIPLINED_RAC_AM_M
# 0.021 SCH_HBDISCIPLINED_RAC_AM_F
# 0.021 SCH_HBDISCIPLINED_RAC_AS_M
# 0.021 SCH_HBDISCIPLINED_RAC_AS_F
# 0.021 SCH_HBDISCIPLINED_RAC_HP_M
# 0.021 SCH_HBDISCIPLINED_RAC_HP_F
# 0.021 SCH_HBDISCIPLINED_RAC_BL_M
# 0.021 SCH_HBDISCIPLINED_RAC_BL_F
# 0.021 SCH_HBDISCIPLINED_RAC_WH_M
# 0.021 SCH_HBDISCIPLINED_RAC_WH_F
# 0.021 SCH_HBDISCIPLINED_RAC_TR_M
# 0.021 SCH_HBDISCIPLINED_RAC_TR_F
# 0.021 TOT_HBDISCIPLINED_RAC_M
# 0.021 TOT_HBDISCIPLINED_RAC_F
# 0.021 SCH_HBDISCIPLINED_RAC_LEP_M
# 0.021 SCH_HBDISCIPLINED_RAC_LEP_F
# 0.021 SCH_HBDISCIPLINED_RAC_IDEA_M
# 0.021 SCH_HBDISCIPLINED_RAC_IDEA_F
# 0.021 SCH_HBDISCIPLINED_RAC_504_M
# 0.021 SCH_HBDISCIPLINED_RAC_504_F
# 0.02 SCH_HBDISCIPLINED_DIS_HI_M
# 0.02 SCH_HBDISCIPLINED_DIS_HI_F
# 0.02 SCH_HBDISCIPLINED_DIS_AM_M
# 0.02 SCH_HBDISCIPLINED_DIS_AM_F
# 0.02 SCH_HBDISCIPLINED_DIS_AS_M
# 0.02 SCH_HBDISCIPLINED_DIS_AS_F
# 0.02 SCH_HBDISCIPLINED_DIS_HP_M
# 0.02 SCH_HBDISCIPLINED_DIS_HP_F
# 0.02 SCH_HBDISCIPLINED_DIS_BL_M
# 0.02 SCH_HBDISCIPLINED_DIS_BL_F
# 0.02 SCH_HBDISCIPLINED_DIS_WH_M
# 0.02 SCH_HBDISCIPLINED_DIS_WH_F
# 0.02 SCH_HBDISCIPLINED_DIS_TR_M
# 0.02 SCH_HBDISCIPLINED_DIS_TR_F
# 0.02 TOT_HBDISCIPLINED_DIS_M
# 0.02 TOT_HBDISCIPLINED_DIS_F
# 0.02 SCH_HBDISCIPLINED_DIS_LEP_M
# 0.02 SCH_HBDISCIPLINED_DIS_LEP_F
# 0.02 SCH_HBDISCIPLINED_DIS_IDEA_M
# 0.02 SCH_HBDISCIPLINED_DIS_IDEA_F
# 0.02 SCH_HBDISCIPLINED_DIS_504_M
# 0.02 SCH_HBDISCIPLINED_DIS_504_F
# 0.019 SCH_ABSENT_HI_M
# 0.019 SCH_ABSENT_HI_F
# 0.019 SCH_ABSENT_AM_M
# 0.019 SCH_ABSENT_AM_F
# 0.019 SCH_ABSENT_AS_M
# 0.019 SCH_ABSENT_AS_F
# 0.019 SCH_ABSENT_HP_M
# 0.019 SCH_ABSENT_HP_F
# 0.019 SCH_ABSENT_BL_M
# 0.019 SCH_ABSENT_BL_F
# 0.019 SCH_ABSENT_WH_M
# 0.019 SCH_ABSENT_WH_F
# 0.019 SCH_ABSENT_TR_M
# 0.019 SCH_ABSENT_TR_F
# 0.019 TOT_ABSENT_M
# 0.019 TOT_ABSENT_F
# 0.019 SCH_ABSENT_LEP_M
# 0.019 SCH_ABSENT_LEP_F
# 0.019 SCH_ABSENT_504_M
# 0.019 SCH_ABSENT_504_F
# 0.019 SCH_ABSENT_IDEA_M
# 0.019 SCH_ABSENT_IDEA_F
# 0.468 SCH_RET_KG_IND
# 0.462 SCH_RET_G01_IND
# 0.462 SCH_RET_G02_IND
# 0.462 SCH_RET_G03_IND
# 0.465 SCH_RET_G04_IND
# 0.481 SCH_RET_G05_IND
# 0.636 SCH_RET_G06_IND
# 0.693 SCH_RET_G07_IND
# 0.691 SCH_RET_G08_IND
# 0.747 SCH_RET_G09_IND
# 0.745 SCH_RET_G10_IND
# 0.744 SCH_RET_G11_IND
# 0.745 SCH_RET_G12_IND
# 0.733 SCH_RET_KG_HI_M
# 0.733 SCH_RET_KG_HI_F
# 0.733 SCH_RET_KG_AM_M
# 0.733 SCH_RET_KG_AM_F
# 0.733 SCH_RET_KG_AS_M
# 0.733 SCH_RET_KG_AS_F
# 0.733 SCH_RET_KG_HP_M
# 0.733 SCH_RET_KG_HP_F
# 0.733 SCH_RET_KG_BL_M
# 0.733 SCH_RET_KG_BL_F
# 0.733 SCH_RET_KG_WH_M
# 0.733 SCH_RET_KG_WH_F
# 0.733 SCH_RET_KG_TR_M
# 0.733 SCH_RET_KG_TR_F
# 0.733 TOT_RET_KG_M
# 0.733 TOT_RET_KG_F
# 0.733 SCH_RET_KG_LEP_M
# 0.733 SCH_RET_KG_LEP_F
# 0.733 SCH_RET_KG_IDEA_M
# 0.733 SCH_RET_KG_IDEA_F
# 0.733 SCH_RET_KG_504_M
# 0.733 SCH_RET_KG_504_F
# 0.768 SCH_RET_G01_HI_M
# 0.768 SCH_RET_G01_HI_F
# 0.768 SCH_RET_G01_AM_M
# 0.768 SCH_RET_G01_AM_F
# 0.768 SCH_RET_G01_AS_M
# 0.768 SCH_RET_G01_AS_F
# 0.768 SCH_RET_G01_HP_M
# 0.768 SCH_RET_G01_HP_F
# 0.768 SCH_RET_G01_BL_M
# 0.768 SCH_RET_G01_BL_F
# 0.768 SCH_RET_G01_WH_M
# 0.768 SCH_RET_G01_WH_F
# 0.768 SCH_RET_G01_TR_M
# 0.768 SCH_RET_G01_TR_F
# 0.768 TOT_RET_G01_M
# 0.768 TOT_RET_G01_F
# 0.768 SCH_RET_G01_LEP_M
# 0.768 SCH_RET_G01_LEP_F
# 0.768 SCH_RET_G01_IDEA_M
# 0.768 SCH_RET_G01_IDEA_F
# 0.768 SCH_RET_G01_504_M
# 0.768 SCH_RET_G01_504_F
# 0.833 SCH_RET_G02_HI_M
# 0.833 SCH_RET_G02_HI_F
# 0.833 SCH_RET_G02_AM_M
# 0.833 SCH_RET_G02_AM_F
# 0.833 SCH_RET_G02_AS_M
# 0.833 SCH_RET_G02_AS_F
# 0.833 SCH_RET_G02_HP_M
# 0.833 SCH_RET_G02_HP_F
# 0.833 SCH_RET_G02_BL_M
# 0.833 SCH_RET_G02_BL_F
# 0.833 SCH_RET_G02_WH_M
# 0.833 SCH_RET_G02_WH_F
# 0.833 SCH_RET_G02_TR_M
# 0.833 SCH_RET_G02_TR_F
# 0.833 TOT_RET_G02_M
# 0.833 TOT_RET_G02_F
# 0.833 SCH_RET_G02_LEP_M
# 0.833 SCH_RET_G02_LEP_F
# 0.833 SCH_RET_G02_IDEA_M
# 0.833 SCH_RET_G02_IDEA_F
# 0.833 SCH_RET_G02_504_M
# 0.833 SCH_RET_G02_504_F
# 0.859 SCH_RET_G03_HI_M
# 0.859 SCH_RET_G03_HI_F
# 0.859 SCH_RET_G03_AM_M
# 0.859 SCH_RET_G03_AM_F
# 0.859 SCH_RET_G03_AS_M
# 0.859 SCH_RET_G03_AS_F
# 0.859 SCH_RET_G03_HP_M
# 0.859 SCH_RET_G03_HP_F
# 0.859 SCH_RET_G03_BL_M
# 0.859 SCH_RET_G03_BL_F
# 0.859 SCH_RET_G03_WH_M
# 0.859 SCH_RET_G03_WH_F
# 0.859 SCH_RET_G03_TR_M
# 0.859 SCH_RET_G03_TR_F
# 0.859 TOT_RET_G03_M
# 0.859 TOT_RET_G03_F
# 0.859 SCH_RET_G03_LEP_M
# 0.859 SCH_RET_G03_LEP_F
# 0.859 SCH_RET_G03_IDEA_M
# 0.859 SCH_RET_G03_IDEA_F
# 0.859 SCH_RET_G03_504_M
# 0.859 SCH_RET_G03_504_F
# 0.915 SCH_RET_G04_HI_M
# 0.915 SCH_RET_G04_HI_F
# 0.915 SCH_RET_G04_AM_M
# 0.915 SCH_RET_G04_AM_F
# 0.915 SCH_RET_G04_AS_M
# 0.915 SCH_RET_G04_AS_F
# 0.915 SCH_RET_G04_HP_M
# 0.915 SCH_RET_G04_HP_F
# 0.915 SCH_RET_G04_BL_M
# 0.915 SCH_RET_G04_BL_F
# 0.915 SCH_RET_G04_WH_M
# 0.915 SCH_RET_G04_WH_F
# 0.915 SCH_RET_G04_TR_M
# 0.915 SCH_RET_G04_TR_F
# 0.915 TOT_RET_G04_M
# 0.915 TOT_RET_G04_F
# 0.915 SCH_RET_G04_LEP_M
# 0.915 SCH_RET_G04_LEP_F
# 0.915 SCH_RET_G04_IDEA_M
# 0.915 SCH_RET_G04_IDEA_F
# 0.915 SCH_RET_G04_504_M
# 0.915 SCH_RET_G04_504_F
# 0.932 SCH_RET_G05_HI_M
# 0.932 SCH_RET_G05_HI_F
# 0.932 SCH_RET_G05_AM_M
# 0.932 SCH_RET_G05_AM_F
# 0.932 SCH_RET_G05_AS_M
# 0.932 SCH_RET_G05_AS_F
# 0.932 SCH_RET_G05_HP_M
# 0.932 SCH_RET_G05_HP_F
# 0.932 SCH_RET_G05_BL_M
# 0.932 SCH_RET_G05_BL_F
# 0.932 SCH_RET_G05_WH_M
# 0.932 SCH_RET_G05_WH_F
# 0.932 SCH_RET_G05_TR_M
# 0.932 SCH_RET_G05_TR_F
# 0.932 TOT_RET_G05_M
# 0.932 TOT_RET_G05_F
# 0.932 SCH_RET_G05_LEP_M
# 0.932 SCH_RET_G05_LEP_F
# 0.932 SCH_RET_G05_IDEA_M
# 0.932 SCH_RET_G05_IDEA_F
# 0.932 SCH_RET_G05_504_M
# 0.932 SCH_RET_G05_504_F
# 0.934 SCH_RET_G06_HI_M
# 0.934 SCH_RET_G06_HI_F
# 0.934 SCH_RET_G06_AM_M
# 0.934 SCH_RET_G06_AM_F
# 0.934 SCH_RET_G06_AS_M
# 0.934 SCH_RET_G06_AS_F
# 0.934 SCH_RET_G06_HP_M
# 0.934 SCH_RET_G06_HP_F
# 0.934 SCH_RET_G06_BL_M
# 0.934 SCH_RET_G06_BL_F
# 0.934 SCH_RET_G06_WH_M
# 0.934 SCH_RET_G06_WH_F
# 0.934 SCH_RET_G06_TR_M
# 0.934 SCH_RET_G06_TR_F
# 0.934 TOT_RET_G06_M
# 0.934 TOT_RET_G06_F
# 0.934 SCH_RET_G06_LEP_M
# 0.934 SCH_RET_G06_LEP_F
# 0.934 SCH_RET_G06_IDEA_M
# 0.934 SCH_RET_G06_IDEA_F
# 0.934 SCH_RET_G06_504_M
# 0.934 SCH_RET_G06_504_F
# 0.929 SCH_RET_G07_HI_M
# 0.929 SCH_RET_G07_HI_F
# 0.929 SCH_RET_G07_AM_M
# 0.929 SCH_RET_G07_AM_F
# 0.929 SCH_RET_G07_AS_M
# 0.929 SCH_RET_G07_AS_F
# 0.929 SCH_RET_G07_HP_M
# 0.929 SCH_RET_G07_HP_F
# 0.929 SCH_RET_G07_BL_M
# 0.929 SCH_RET_G07_BL_F
# 0.929 SCH_RET_G07_WH_M
# 0.929 SCH_RET_G07_WH_F
# 0.929 SCH_RET_G07_TR_M
# 0.929 SCH_RET_G07_TR_F
# 0.929 TOT_RET_G07_M
# 0.929 TOT_RET_G07_F
# 0.929 SCH_RET_G07_LEP_M
# 0.929 SCH_RET_G07_LEP_F
# 0.929 SCH_RET_G07_IDEA_M
# 0.929 SCH_RET_G07_IDEA_F
# 0.929 SCH_RET_G07_504_M
# 0.929 SCH_RET_G07_504_F
# 0.928 SCH_RET_G08_HI_M
# 0.928 SCH_RET_G08_HI_F
# 0.928 SCH_RET_G08_AM_M
# 0.928 SCH_RET_G08_AM_F
# 0.928 SCH_RET_G08_AS_M
# 0.928 SCH_RET_G08_AS_F
# 0.928 SCH_RET_G08_HP_M
# 0.928 SCH_RET_G08_HP_F
# 0.928 SCH_RET_G08_BL_M
# 0.928 SCH_RET_G08_BL_F
# 0.928 SCH_RET_G08_WH_M
# 0.928 SCH_RET_G08_WH_F
# 0.928 SCH_RET_G08_TR_M
# 0.928 SCH_RET_G08_TR_F
# 0.928 TOT_RET_G08_M
# 0.928 TOT_RET_G08_F
# 0.928 SCH_RET_G08_LEP_M
# 0.928 SCH_RET_G08_LEP_F
# 0.928 SCH_RET_G08_IDEA_M
# 0.928 SCH_RET_G08_IDEA_F
# 0.928 SCH_RET_G08_504_M
# 0.928 SCH_RET_G08_504_F
# 0.905 SCH_RET_G09_HI_M
# 0.905 SCH_RET_G09_HI_F
# 0.905 SCH_RET_G09_AM_M
# 0.905 SCH_RET_G09_AM_F
# 0.905 SCH_RET_G09_AS_M
# 0.905 SCH_RET_G09_AS_F
# 0.905 SCH_RET_G09_HP_M
# 0.905 SCH_RET_G09_HP_F
# 0.905 SCH_RET_G09_BL_M
# 0.905 SCH_RET_G09_BL_F
# 0.905 SCH_RET_G09_WH_M
# 0.905 SCH_RET_G09_WH_F
# 0.905 SCH_RET_G09_TR_M
# 0.905 SCH_RET_G09_TR_F
# 0.905 TOT_RET_G09_M
# 0.905 TOT_RET_G09_F
# 0.905 SCH_RET_G09_LEP_M
# 0.905 SCH_RET_G09_LEP_F
# 0.905 SCH_RET_G09_IDEA_M
# 0.905 SCH_RET_G09_IDEA_F
# 0.905 SCH_RET_G09_504_M
# 0.905 SCH_RET_G09_504_F
# 0.908 SCH_RET_G10_HI_M
# 0.908 SCH_RET_G10_HI_F
# 0.908 SCH_RET_G10_AM_M
# 0.908 SCH_RET_G10_AM_F
# 0.908 SCH_RET_G10_AS_M
# 0.908 SCH_RET_G10_AS_F
# 0.908 SCH_RET_G10_HP_M
# 0.908 SCH_RET_G10_HP_F
# 0.908 SCH_RET_G10_BL_M
# 0.908 SCH_RET_G10_BL_F
# 0.908 SCH_RET_G10_WH_M
# 0.908 SCH_RET_G10_WH_F
# 0.908 SCH_RET_G10_TR_M
# 0.908 SCH_RET_G10_TR_F
# 0.908 TOT_RET_G10_M
# 0.908 TOT_RET_G10_F
# 0.908 SCH_RET_G10_LEP_M
# 0.908 SCH_RET_G10_LEP_F
# 0.908 SCH_RET_G10_IDEA_M
# 0.908 SCH_RET_G10_IDEA_F
# 0.908 SCH_RET_G10_504_M
# 0.908 SCH_RET_G10_504_F
# 0.915 SCH_RET_G11_HI_M
# 0.915 SCH_RET_G11_HI_F
# 0.915 SCH_RET_G11_AM_M
# 0.915 SCH_RET_G11_AM_F
# 0.915 SCH_RET_G11_AS_M
# 0.915 SCH_RET_G11_AS_F
# 0.915 SCH_RET_G11_HP_M
# 0.915 SCH_RET_G11_HP_F
# 0.915 SCH_RET_G11_BL_M
# 0.915 SCH_RET_G11_BL_F
# 0.915 SCH_RET_G11_WH_M
# 0.915 SCH_RET_G11_WH_F
# 0.915 SCH_RET_G11_TR_M
# 0.915 SCH_RET_G11_TR_F
# 0.915 TOT_RET_G11_M
# 0.915 TOT_RET_G11_F
# 0.915 SCH_RET_G11_LEP_M
# 0.915 SCH_RET_G11_LEP_F
# 0.915 SCH_RET_G11_IDEA_M
# 0.915 SCH_RET_G11_IDEA_F
# 0.915 SCH_RET_G11_504_M
# 0.915 SCH_RET_G11_504_F
# 0.88 SCH_RET_G12_HI_M
# 0.88 SCH_RET_G12_HI_F
# 0.88 SCH_RET_G12_AM_M
# 0.88 SCH_RET_G12_AM_F
# 0.88 SCH_RET_G12_AS_M
# 0.88 SCH_RET_G12_AS_F
# 0.88 SCH_RET_G12_HP_M
# 0.88 SCH_RET_G12_HP_F
# 0.88 SCH_RET_G12_BL_M
# 0.88 SCH_RET_G12_BL_F
# 0.88 SCH_RET_G12_WH_M
# 0.88 SCH_RET_G12_WH_F
# 0.88 SCH_RET_G12_TR_M
# 0.88 SCH_RET_G12_TR_F
# 0.88 TOT_RET_G12_M
# 0.88 TOT_RET_G12_F
# 0.88 SCH_RET_G12_LEP_M
# 0.88 SCH_RET_G12_LEP_F
# 0.88 SCH_RET_G12_IDEA_M
# 0.88 SCH_RET_G12_IDEA_F
# 0.88 SCH_RET_G12_504_M
# 0.88 SCH_RET_G12_504_F
# 0.732 SCH_SSATHLETICS_IND
# 0.831 SCH_SSSPORTS_M
# 0.831 SCH_SSSPORTS_F
# 0.831 TOT_SSSPORTS
# 0.831 SCH_SSTEAMS_M
# 0.831 SCH_SSTEAMS_F
# 0.831 TOT_SSTEAMS
# 0.831 SCH_SSPART_M
# 0.831 SCH_SSPART_F
# 0.831 TOT_SSPART
# 0.037 SCH_SAL_TOTPERS_WOFED
# 0.037 SCH_FTE_TEACH_WOFED
# 0.055 SCH_SAL_TEACH_WOFED
# 0.037 SCH_NPE_WOFED
# 0.037 SCH_FTE_AID_WOFED
# 0.037 SCH_SAL_AID_WOFED
# 0.037 SCH_FTE_SUP_WOFED
# 0.037 SCH_SAL_SUP_WOFED
# 0.037 SCH_FTE_ADM_WOFED
# 0.037 SCH_SAL_ADM_WOFED
# 0.017 SCH_SAL_TEACH_WFED
# 0.017 SCH_FTE_AID_WFED
# 0.017 SCH_SAL_AID_WFED
# 0.017 SCH_FTE_SUP_WFED
# 0.017 SCH_SAL_SUP_WFED
# 0.017 SCH_FTE_ADM_WFED
# 0.017 SCH_SAL_ADM_WFED
# 0.017 SCH_SAL_TOTPERS_WFED
# 0.058 SCH_NPE_WFED
# 0.0 SCH_FTETEACH_TOT
# 0.0 SCH_FTETEACH_CERT
# 0.0 SCH_FTETEACH_NOTCERT
# 0.0 SCH_FTETEACH_FY
# 0.0 SCH_FTETEACH_SY
# 0.0 SCH_TEACHERS_CURR_TOT
# 0.0 SCH_TEACHERS_PREV_TOT
# 0.0 SCH_FTECOUNSELORS
# 0.0 SCH_FTETEACH_ABSENT
# 0.736 SCH_FTESECURITY_LEO
# 0.019 SCH_FTESECURITY_GUA
# 0.0 SCH_FTESERVICES_NUR
# 0.0 SCH_FTESERVICES_PSY
# 0.0 SCH_FTESERVICES_SOC
# 0.998 SCH_JJTYPE
# 0.998 SCH_JJSYDAYS
# 0.998 SCH_JJHOURS
# 0.998 SCH_JJPART_LT15
# 0.998 SCH_JJPART_15T30
# 0.998 SCH_JJPART_31T90
# 0.998 SCH_JJPART_91T180
# 0.998 SCH_JJPART_OV180

# %%
nul_vals = [-2,-5,-6,-7,-8,-9, '-2', '-5', '-6','-7','-8','-9']
# for (columnName, columnData) in school_data.iteritems():
column = "SCH_JJTYPE"
print(school_data[column].unique())
print(school_data[column][~school_data[column].isin(nul_vals)])
# Out:
# [-7 -9 '-9' '-7' 'Both' 'Post' 'Pre']
# 2285     Both
# 2390     Both
# 2948     Both
# 2949     Both
# 3978     Both
# 4048     Post
# 4049     Post
# 4050     Post
# 4051     Post
# 4052     Post
# 4053     Post
# 5619     Post
# 5620     Post
# 5621     Post
# 5622     Post
# 14221     Pre
# 14229    Post
# 14236    Both
# 14246    Both
# 14272    Both
# 14314    Both
# 14321    Both
# 14493    Both
# 15167    Both
# 15497     Pre
# 16205    Both
# 22644     Pre
# 22645    Post
# 22646    Post
# 22647    Post
#          ...
# 88786    Both
# 88787    Both
# 88788    Both
# 88789    Both
# 88790    Both
# 88791    Both
# 88792    Both
# 88793    Both
# 88794    Both
# 88795    Both
# 88796    Both
# 88797    Both
# 88798    Both
# 88813    Post
# 90763    Both
# 90764    Both
# 90766    Both
# 90767    Both
# 90768    Both
# 91246    Post
# 91602    Both
# 92061    Post
# 93787    Post
# 93895    Both
# 94334    Both
# 94401    Post
# 95027    Both
# 95908    Both
# 96356    Post
# 96357    Post
# Name: SCH_JJTYPE, dtype: object

# %%
def percentage_of_students(school_layout, school_data,layout_a_start,layout_a_stop):
    enrollment = []
    np.seterr(divide = 'ignore')
    enroll_categories = range(layout_a_start,layout_a_stop+1,1)
    enrollment_vals = np.empty([len(enroll_categories)*len(school_data)])
    enrollment_vals.shape = [len(enroll_categories),len(school_data)]
    for i in range(len(enroll_categories)):
        j = enroll_categories[i]
        print(school_layout['Field_Description'][school_layout['Order']==j].values[0])
        enrollment.append(str(school_layout['Field_Name'][school_layout['Order']==j].values[0]))
        nul_bool = school_data[enrollment[-1]].isin(nul_vals)
        value = np.array(school_data[enrollment[-1]])
        value[nul_bool] = 0
        if i == 0:
            enrollment_vals[0] = value
        else:
            enrollment_vals[i] = value
    return(enrollment_vals)

enrollment = percentage_of_students(school_layout,school_data,56,71)
suspensions = percentage_of_students(school_layout,school_data,822,837)
percentages = suspensions/enrollment
percentages = np.nan_to_num(percentages)
print(np.round(np.mean(suspensions,axis=1),3))
print(np.round(np.mean(enrollment,axis=1),3))
print(np.round(np.mean(suspensions,axis=1)/np.mean(enrollment,axis=1),3))
# Out:
# Overall Student Enrollment: Hispanic Male
# Overall Student Enrollment: Hispanic Female
# Overall Student Enrollment: American Indian/Alaska Native Male
# Overall Student Enrollment: American Indian/Alaska Native Female
# Overall Student Enrollment: Asian Male
# Overall Student Enrollment: Asian Female
# Overall Student Enrollment: Native Hawaiian/Pacific Islander Male
# Overall Student Enrollment: Native Hawaiian/Pacific Islander Female
# Overall Student Enrollment: Black Male
# Overall Student Enrollment: Black Female
# Overall Student Enrollment: White Male
# Overall Student Enrollment: White Female
# Overall Student Enrollment: Two or More Races Male
# Overall Student Enrollment: Two or More Races Female
# Overall Student Enrollment: Calculated Male Total
# Overall Student Enrollment: Calculated Female Total
# Students without disabilities who received only one out-of-school suspension: Hispanic Male
# Students without disabilities who received only one out-of-school suspension: Hispanic Female
# Students without disabilities who received only one out-of-school suspension: American Indian/Alaska Native Male
# Students without disabilities who received only one out-of-school suspension: American Indian/Alaska Native Female
# Students without disabilities who received only one out-of-school suspension: Asian Male
# Students without disabilities who received only one out-of-school suspension: Asian Female
# Students without disabilities who received only one out-of-school suspension: Native Hawaiian/Pacific Islander Male
# Students without disabilities who received only one out-of-school suspension: Native Hawaiian/Pacific Islander Female
# Students without disabilities who received only one out-of-school suspension: Black Male
# Students without disabilities who received only one out-of-school suspension: Black Female
# Students without disabilities who received only one out-of-school suspension: White Male
# Students without disabilities who received only one out-of-school suspension: White Female
# Students without disabilities who received only one out-of-school suspension: Two or More Races Male
# Students without disabilities who received only one out-of-school suspension: Two or More Races Female
# Total number of students without disabilities who received only one out-of-school suspension: Calculated Male Total
# Total number of students without disabilities who received only one out-of-school suspension: Calculated Female Total
# [ 2.049  1.05   0.141  0.08   0.172  0.059  0.042  0.022  2.923  1.963
#   3.006  1.237  0.387  0.208  8.72   4.618]
# [  69.33    65.942    2.961    2.831   13.347   12.798    1.167    1.1
#    41.414   39.594  132.263  123.844    9.291    8.967  269.774  255.075]
# [ 0.03   0.016  0.048  0.028  0.013  0.005  0.036  0.02   0.071  0.05
#   0.023  0.01   0.042  0.023  0.032  0.018]
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:22: RuntimeWarning: invalid value encountered in true_divide
